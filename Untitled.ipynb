# %%
pip install PyMySQL

# %%
import pandas as pd
import sqlalchemy
import pymysql
import pprint
pp = pprint.PrettyPrinter()

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:admin@localhost:3306/test')

# %%
raw_df = pd.read_sql('raw_data',engine)

# %%
raw_df

# %%
# coverting required sheet in df
converter_df = pd.read_csv('Updated Converter_7th Aug - Sheet1 - Copy.csv')
universal_df = pd.read_csv('Updated Cush Sheet as on 17 August - Updated Cush.csv')


# creating column names for the integration
Integration_column = []
no_of_column_not_containing_integration = int(input('Enter a number of column which is not containing Integrations: '))
for i in range(1,len(raw_df.columns)-(no_of_column_not_containing_integration-1)):
    Integration_column.append('Integration '+str(i))
# pp.pprint(Integration_column)


other_column = []
for i in range(no_of_column_not_containing_integration):
    col = input('Enter name of column '+ str(i+1)+' which are not containing integrations: ')
    other_column.append(col)
pp.pprint(other_column)

new_cols = other_column + Integration_column
raw_df.columns = new_cols

# coverting only integration column of raw_df to dataframe
Integration_df = raw_df[Integration_column]
# pp.pprint(Integration_df)

dictionary = {'/':' ','\s+':' ',r'^\s+':'',r'\s+$':''}   # replace '/' with " ", '\s+' with " ", r'^\s+'->left strip,r'\s+$'->Right strip
Integration_df.replace(dictionary,regex=True,inplace=True)

# replacing null cells with space
Integration_df.replace('','zzz',inplace=True)


# making a list of integration available in the raw_df
Integration_list = []
for i in range(len(Integration_df.index)):
    Integration_list += Integration_df.values[i].tolist()



# making a new list for distinct integrations available in AB_df
unique_integration_set = set(Integration_list)
unique_integration_list = list(unique_integration_set)
# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))

unique_integration_list = [i for i in unique_integration_list if str(i)!= 'nan']
print(len(unique_integration_list))


# list Software name available in converter df
Software_Name = converter_df['Software Name'].tolist()
# pp.pprint(Software_Name)

# list Actual spelling of Software name available in converter df
Actual_Spelling = converter_df['Actual Spelling'].tolist()
# pp.pprint(Actual_Spelling)


# making dictionary to map Software Name to their Actual Spelling
converter_dictionary = {}
for key in Software_Name:
    for value in Actual_Spelling:
        converter_dictionary[key] = value
        Actual_Spelling.remove(value)
        break

# pp.pprint(converter_dictionary)


# making list of Integration available in universal sheet
universal_integration_list = universal_df['Software Name'].tolist()
unique_universal_integration_list = list(set(universal_integration_list))
# pp.pprint(len(sorted(universal_integration_list)))


# making dictionary for unique universal integration list
universal_integration_dictionary = {}
for key in unique_universal_integration_list:
    for value in unique_universal_integration_list:
        if key == value:
            universal_integration_dictionary[key] = value
            break
# pp.pprint(universal_integration_dictionary)


# merging universal integration dictionary and converter dictionary
universal_integration_dictionary.update(converter_dictionary)
# print('universal integration dictionary: '+str(len(universal_integration_dictionary)))


found_integration_dct = {}
# step 1
# In this step elements of unique_integration_list are searched in universal_integration_list keys
# and if element of unique_integration_list found in universal_integration_dictionary
# then this element is changed to its standard value using universal_integration_dictionary
# values and updated in the AB_df
found_integration_list_in_step1 = []
found_integration_dct_in_step1 = {}
not_found_integration_in_step1 = []
for i in range(len(unique_integration_list)):
    for key,value in universal_integration_dictionary.items():
        if str(key).casefold() == str(unique_integration_list[i]).casefold():
            Integration_df.replace(to_replace=unique_integration_list[i], value=value,inplace=True)
            found_integration_list_in_step1.append(unique_integration_list[i])
            found_integration_dct_in_step1[key] = value
            break
    else:
        not_found_integration_in_step1.append(unique_integration_list[i])
found_integration_dct.update(found_integration_dct_in_step1)

# print('Integration found in step1: ' + str(len(found_integration_list_in_step1)))
# print('Integration not found in step1: '+str(len(not_found_integration_in_step1)))
# print('found_integration_dct length after step 1: '+ str(len(found_integration_dct)))



# step 2 
# In this step space between integrations are removed and then convert all integration in lower case
# then this integration names are searched in the dictionary by converting all dictionary key and value
# in lower and replace space between integration name. one dictionary is made for the integrations which are found 
# which were not found in previous step named dct. After this search the not found integration in previous step and 
# search it in dct, and change it with value available in dct.
found_integration_dct_in_step2 = {}
found_integration_in_step2 = []

for i in range(len(not_found_integration_in_step1)):
    for key,value in universal_integration_dictionary.items():
        if str(not_found_integration_in_step1[i]).casefold().replace(' ','') == str(key).casefold().replace(' ',''):
            found_integration_dct_in_step2[not_found_integration_in_step1[i]] = value
            found_integration_in_step2.append(not_found_integration_in_step1[i])
            break

not_found_integration_in_step2 = list(set(not_found_integration_in_step1)-set(found_integration_in_step2))
# print('not found integration after step 2: '+str(len(not_found_integration_in_step2)))

found_integration_dct.update(found_integration_dct_in_step2)
# print('found integration dct after step 2: '+str(len(found_integration_dct)))
# del found_integration_dct['zzz']       

# pp.pprint(dct)
# print('found integration in step 2 '+ str(len(found_integration_in_step2)))



for i in range(len(found_integration_in_step2)):
    for key,value in found_integration_dct_in_step2.items():
        if found_integration_in_step2[i].casefold().replace(' ','') == key.casefold().replace(' ',''):
            Integration_df.replace(to_replace=found_integration_in_step2[i],value=value, inplace=True)
            break


not_found_integration = not_found_integration_in_step2
for i in range(len(not_found_integration)):
    Integration_df.replace(not_found_integration[i],'zzz',inplace=True)

other_column_df = raw_df[other_column]
final_df = pd.concat([other_column_df,Integration_df],axis=1)



sn2an_df = pd.DataFrame(sorted(list(found_integration_dct.items())), columns=['Software Name','Actual Name'])
sn2an_notfound_df = pd.DataFrame(not_found_integration, columns=['Software Name'])

# %%
final_df

# %%
Integration_df

# %%
Integration = Integration_df.values.tolist()

# %%
count = 0
for i in range(len(Integration)):
    for j in range(len(Integration[i])):
        if Integration[i][j] == 'salesforce crm':
            count+=1

# %%
count

# %%
raw_df = pd.read_excel('Raw Data_Sales Intelligence.xlsx')
# coverting required sheet in df
converter_df = pd.read_csv('Updated Converter_7th Aug - Sheet1.csv')
universal_df = pd.read_csv('Updated Cush Sheet as on 17 August - Updated Cush.csv')


# creating column names for the integration
Integration_column = []
no_of_column_not_containing_integration = int(input('Enter a number of column which is not containing Integrations: '))
for i in range(1,len(raw_df.columns)-(no_of_column_not_containing_integration-1)):
    Integration_column.append('Integration '+str(i))
# pp.pprint(Integration_column)


other_column = []
for i in range(no_of_column_not_containing_integration):
    col = input('Enter name of column '+ str(i+1)+' which are not containing integrations: ')
    other_column.append(col)
pp.pprint(other_column)

new_cols = other_column + Integration_column
raw_df.columns = new_cols

# coverting only integration column of raw_df to dataframe
Integration_df = raw_df[Integration_column]
# pp.pprint(Integration_df)

dictionary = {'/':' ','\s+':' ',r'^\s+':'',r'\s+$':''}   # replace '/' with " ", '\s+' with " ", r'^\s+'->left strip,r'\s+$'->Right strip
Integration_df.replace(dictionary,regex=True,inplace=True)

# replacing null cells with space
Integration_df.replace('','zzz',inplace=True)


# making a list of integration available in the raw_df
Integration_list = []
for i in range(len(Integration_df.index)):
    Integration_list += Integration_df.values[i].tolist()


# making a new list for distinct integrations available in AB_df
unique_integration_set = set(Integration_list)
old_unique_integration_list = list(unique_integration_set)
# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))
integration_list_lower = []
for i in range(len(old_unique_integration_list)):
    integration_list_lower.append(str(old_unique_integration_list[i]).lower().replace(' ',''))

unique_integration_list_lower = list(set(integration_list_lower))
# print(len(unique_integration_list_lower))

unique_integration_dict = {}
for key in unique_integration_list_lower:
    for value in old_unique_integration_list:
        if key == str(value).lower().replace(' ',''):
            unique_integration_dict[key] = value 
            del key
            break
# print(len(unique_integration_dict))

unique_integration_list = []

for value in unique_integration_dict.values():
    unique_integration_list.append(str(value))

# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))


# removiung nan from unique_integration_list
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'nan']
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'zzz']

print('unique integration list: '+ str(len(unique_integration_list)))

# list Software name available in converter df
Software_Name = converter_df['Software Name'].tolist()
# pp.pprint(Software_Name)

# list Actual spelling of Software name available in converter df
Actual_Spelling = converter_df['Actual Spelling'].tolist()
# pp.pprint(Actual_Spelling)


# making dictionary to map Software Name to their Actual Spelling
converter_dictionary = {}
for key in Software_Name:
    for value in Actual_Spelling:
        converter_dictionary[key] = value
        Actual_Spelling.remove(value)
        break
# pp.pprint(converter_dictionary)


# making list of Integration available in universal sheet
universal_integration_list = universal_df['Software Name'].tolist()
unique_universal_integration_list = list(set(universal_integration_list))
# pp.pprint(len(sorted(universal_integration_list)))


# making dictionary for unique universal integration list
universal_integration_dictionary = {}
for key in unique_universal_integration_list:
    for value in unique_universal_integration_list:
        if key == value:
            universal_integration_dictionary[key] = value
            break
# pp.pprint(universal_integration_dictionary)


# merging universal integration dictionary and converter dictionary
universal_integration_dictionary.update(converter_dictionary)
# print('universal integration dictionary: '+str(len(universal_integration_dictionary)))


found_integration_dct = {}
# step 1
# In this step elements of unique_integration_list are searched in universal_integration_list keys
# and if element of unique_integration_list found in universal_integration_dictionary
# then this element is changed to its standard value using universal_integration_dictionary
# values and updated in the AB_df
found_integration_list_in_step1 = []
found_integration_dct_in_step1 = {}
not_found_integration_in_step1 = []
for i in range(len(unique_integration_list)):
    for key,value in universal_integration_dictionary.items():
        if str(key).casefold() == str(unique_integration_list[i]).casefold():
            Integration_df.replace(to_replace=unique_integration_list[i], value=value,inplace=True)
            found_integration_list_in_step1.append(unique_integration_list[i])
            found_integration_dct_in_step1[key] = value
            break
    else:
        not_found_integration_in_step1.append(unique_integration_list[i])
found_integration_dct.update(found_integration_dct_in_step1)

# print('Integration found in step1: ' + str(len(found_integration_list_in_step1)))
# print('Integration not found in step1: '+str(len(not_found_integration_in_step1)))
# print('found_integration_dct length after step 1: '+ str(len(found_integration_dct)))



# step 2 
# In this step space between integrations are removed and then convert all integration in lower case
# then this integration names are searched in the dictionary by converting all dictionary key and value
# in lower and replace space between integration name. one dictionary is made for the integrations which are found 
# which were not found in previous step named dct. After this search the not found integration in previous step and 
# search it in dct, and change it with value available in dct.
found_integration_dct_in_step2 = {}
found_integration_in_step2 = []

for i in range(len(not_found_integration_in_step1)):
    for key,value in universal_integration_dictionary.items():
        if str(not_found_integration_in_step1[i]).casefold().replace(' ','') == str(key).casefold().replace(' ',''):
            found_integration_dct_in_step2[not_found_integration_in_step1[i]] = value
            found_integration_in_step2.append(not_found_integration_in_step1[i])
            break

not_found_integration_in_step2 = list(set(not_found_integration_in_step1)-set(found_integration_in_step2))
# print('not found integration after step 2: '+str(len(not_found_integration_in_step2)))

found_integration_dct.update(found_integration_dct_in_step2)
# print('found integration dct after step 2: '+str(len(found_integration_dct)))
# del found_integration_dct['zzz']       

# pp.pprint(dct)
# print('found integration in step 2 '+ str(len(found_integration_in_step2)))



for i in range(len(found_integration_in_step2)):
    for key,value in found_integration_dct_in_step2.items():
        if found_integration_in_step2[i].casefold().replace(' ','') == key.casefold().replace(' ',''):
            Integration_df.replace(to_replace=found_integration_in_step2[i],value=value, inplace=True)
            break

integration_lol = Integration_df.to_numpy().tolist()  # this will give list of list of row wise integrations

s2c = [list(i) for i in universal_df.itertuples(index=False)] # converted softwarename list available in to universal sheet into list of lists


cat = []   # category list
cat_lol = []   # category list of list row wise

# in this category according to integration name is given in output list cat which stands for category
# this category list will converted into list of list and appended it cat_lol which stands for 
# category list of list
for i in range(len(integration_lol)):
    cat.clear()
    for j in range(len(integration_lol[i])):
        for k in range(len(s2c)):
            if integration_lol[i][j] == s2c[k][0]:
                cat.append(s2c[k][1])
                
    cat = [cat]
    cat_lol += cat

category_df = pd.DataFrame(cat_lol)   # cat_lol is converted to dataframe

L1_L2_cat_list = category_df.values.tolist()

L1_L2_cat_list = [[str(L1_L2_cat_list[i][j]) for j in range(len(L1_L2_cat_list[i])) if str(L1_L2_cat_list[i][j]) != 'None']for i in range(len(L1_L2_cat_list))]

L1_L2_cat_lol = [[[str(L1_L2_cat_list[i][j])]for j in range(len(L1_L2_cat_list[i]))]for i in range(len(L1_L2_cat_list))]

for i in range(len(L1_L2_cat_lol)):
    for j in range(len(L1_L2_cat_lol[i])):
        for k in range(len(L1_L2_cat_lol[i][j])):
            L1_L2_cat_lol[i][j].append(L1_L2_cat_lol[i][j][k].split(' - ',1))
        for l in range(len(L1_L2_cat_lol[i][j][1])):
            L1_L2_cat_lol[i][j].append(L1_L2_cat_lol[i][j][1][l])


new_L1_L2_cat = []
for i in range(len(L1_L2_cat_lol)):
    for j in range(len(L1_L2_cat_lol[i])):
        new_L1_L2_cat.append(L1_L2_cat_lol[i][j])

L1_L2_overall_df = pd.DataFrame(new_L1_L2_cat)

L1_L2_overall_df = L1_L2_overall_df.drop(1,axis=1)

L1_L2_overall_df.columns = ['L1-L2 overall','L1','L2']


L1_count_df = L1_L2_overall_df.groupby(['L1'],as_index=False).count()

L1_count_df = L1_count_df.drop(L1_count_df.iloc[:,[2]],axis=1)

L1_count_df.columns = ['L1','COUNT of L1']
L1_count_df.sort_values(by='COUNT of L1',ascending=False,ignore_index=True,inplace=True)



L2_count_df = L1_L2_overall_df.groupby(['L1','L2'],as_index=False).count()
L2_count_df.columns = ['L1','L2','COUNT of L2']

L2_count_df = L2_count_df.sort_values(by=['L1','COUNT of L2'],ascending=[True,False],ignore_index=True)

pivot_table_df = pd.concat([L1_count_df,L2_count_df],axis=1)




L1_count_list = L1_count_df.values.tolist() # gives list of list of software name and its number of occurance
# pp.pprint(L1_count_list)

L1_graph_lol = []
others_lol = []


# if length of count list is greater or equal to 20 then top 9 softwares are added as it is with their 
# count and other software are added in 'others' and total count of 'others' is summed up and added as
# 'others' count
# if length of countlist is less then 20 then top half of them which contains more no of occurence
# are added as it is with thier count and  remaining half is added to 'others'
if len(L1_count_list)>=20:           
    for i in range(len(L1_count_list)):
        if i<9:
            L1_graph_lol.append(L1_count_list[i])
        else:
            others_lol.append(L1_count_list[i])
else:
    for i in range(int(len(L1_count_list)/2)):
        L1_graph_lol.append(L1_count_list[i])
    for j in range(int(len(L1_count_list)/2),len(L1_count_list)+1):
        others_lol.append(L1_count_list[j])


others = ['other']
sum = 0
for i in range(len(others_lol)):
    sum += others_lol[i][1]
others.append(sum)

L1_graph_lol.append(others)

L1_graph_df = pd.DataFrame(L1_graph_lol,columns=['Software Name','COUNT'])


# L1_graph_df.to_sql(name='Functional Analysis',con=engine,index=False,if_exists='replace')

# <-------------------------------Functional Analysis Completed------------------------------------->


# select top 4 software name which has highest no. of occurence
top_4_soft = []  
for i in range(4):
    top_4_soft.append(L1_count_list[i][0])

L2_count_list = L2_count_df.values.tolist()  # coverts L2_count_df into list of list

# for first software which has highest no. of occurence
# 


first_soft = []
for i in range(len(L2_count_list)):
    if top_4_soft[0] == L2_count_list[i][0]:
        first_soft.append(L2_count_list[i])

# it will give list of list of L1, L2 and occurence of L2. we need only L2 and its occurence

for i in range(len(first_soft)):
    del first_soft[i][0]

# it will remove L1 from first soft list of list

first_soft_graph = []   #software names which are included in graph
first_soft_others = []   # software which are not in first_soft graph are added in this list

# if length of first soft is greater or equal to 20 then top 9 softwares are added as it is with their 
# count and other software are added in first_soft_others and total count of first_soft_others
# is summed up and added as 'others' count
# if length of first_soft is less then 20 then top half of them which contains more no of occurence
# are added as it is with thier count and  remaining half is added to 'first_soft_others'
if len(first_soft)>=20:           
    for i in range(len(first_soft)):
        if i<9:
            first_soft_graph.append(first_soft[i])
        else:
            first_soft_others.append(first_soft[i])
else:
    for i in range(int(len(first_soft)/2)):
        first_soft_graph.append(first_soft[i])
    for j in range(int(len(first_soft)/2),len(first_soft)):
        first_soft_others.append(first_soft[j])


# counting the occurence of software available in first_soft_others
others = ['other']
add = 0
for i in range(len(first_soft_others)):
    add = add + first_soft_others[i][1]
others.append(add)

first_soft_graph.append(others)


first_soft_df = pd.DataFrame(first_soft,columns=['L1','COUNT'])
first_soft_graph_df = pd.DataFrame(first_soft_graph,columns=['L1','COUNT'])

first_soft_final_df = pd.concat([first_soft_df,first_soft_graph_df],axis=1)


# first_soft_final_df.to_sql(name=top_4_soft[0],con=engine,index=False,if_exists='replace')

# <---------------------------Highest no. of L2 occurence graph details completed-------------------------------->



second_soft = []
for i in range(len(L2_count_list)):
    if top_4_soft[1] == L2_count_list[i][0]:
        second_soft.append(L2_count_list[i])

# it will give list of list of L1, L2 and occurence of L2. we need only L2 and its occurence

for i in range(len(second_soft)):
    del second_soft[i][0]

# it will remove L1 from first soft list of list

second_soft_graph = []   #software names which are included in graph
second_soft_others = []   # software which are not in second_soft_graph are added in this list


if len(second_soft)>=20:           
    for i in range(len(second_soft)):
        if i<9:
            second_soft_graph.append(second_soft[i])
        else:
            second_soft_others.append(second_soft[i])
else:
    for i in range(int(len(second_soft)/2)):
        second_soft_graph.append(second_soft[i])
    for j in range(int(len(second_soft)/2),len(second_soft)):
        second_soft_others.append(second_soft[j])



others = ['other']
add = 0
for i in range(len(second_soft_others)):
    add = add + second_soft_others[i][1]
others.append(add)

second_soft_graph.append(others)


second_soft_df = pd.DataFrame(second_soft,columns=['L1','COUNT'])   
second_soft_graph_df = pd.DataFrame(second_soft_graph,columns=['L1','COUNT'])

second_soft_final_df = pd.concat([second_soft_df,second_soft_graph_df],axis=1)


# second_soft_final_df.to_sql(name=top_4_soft[1],con=engine,index=False,if_exists='replace')


# <--------------------------Second Highest no. of L2 occurence graph details completed-------------------------------->


third_soft = []
for i in range(len(L2_count_list)):
    if top_4_soft[2] == L2_count_list[i][0]:
        third_soft.append(L2_count_list[i])

# it will give list of list of L1, L2 and occurence of L2. we need only L2 and its occurence

for i in range(len(third_soft)):
    del third_soft[i][0]

# it will remove L1 from first soft list of list

third_soft_graph = []   #software names which are included in graph
third_soft_others = []   # software which are not in second_soft_graph are added in this list

if len(third_soft)>=20:           
    for i in range(len(third_soft)):
        if i<9:
            third_soft_graph.append(third_soft[i])
        else:
            third_soft_others.append(third_soft[i])
else:
    for i in range(int(len(third_soft)/2)):
        third_soft_graph.append(third_soft[i])
    for j in range(int(len(third_soft)/2),len(third_soft)):
        third_soft_others.append(third_soft[j])



others = ['other']
add = 0
for i in range(len(third_soft_others)):
    add = add + third_soft_others[i][1]
others.append(add)

third_soft_graph.append(others)


third_soft_df = pd.DataFrame(third_soft,columns=['L1','COUNT'])   
third_soft_graph_df = pd.DataFrame(third_soft_graph,columns=['L1','COUNT'])

third_soft_final_df = pd.concat([third_soft_df,third_soft_graph_df],axis=1)


# third_soft_final_df.to_sql(name=top_4_soft[2],con=engine,index=False,if_exists='replace')


# <--------------------------Third Highest no. of L2 occurence graph details completed-------------------------------->


fourth_soft = []
for i in range(len(L2_count_list)):
    if top_4_soft[3] == L2_count_list[i][0]:
        fourth_soft.append(L2_count_list[i])

# it will give list of list of L1, L2 and occurence of L2. we need only L2 and its occurence

for i in range(len(fourth_soft)):
    del fourth_soft[i][0]

# it will remove L1 from first soft list of list

fourth_soft_graph = []   #software names which are included in graph
fourth_soft_others = []   # software which are not in second_soft_graph are added in this list

if len(fourth_soft)>=20:           
    for i in range(len(fourth_soft)):
        if i<9:
            fourth_soft_graph.append(fourth_soft[i])
        else:
            fourth_soft_others.append(fourth_soft[i])
else:
    for i in range(int(len(fourth_soft)/2)):
        fourth_soft_graph.append(fourth_soft[i])
    for j in range(int(len(fourth_soft)/2),len(fourth_soft)):
        fourth_soft_others.append(fourth_soft[j])



others = ['other']
add = 0
for i in range(len(fourth_soft_others)):
    add = add + fourth_soft_others[i][1]
others.append(add)

fourth_soft_graph.append(others)


fourth_soft_df = pd.DataFrame(fourth_soft,columns=['L1','COUNT'])   
fourth_soft_graph_df = pd.DataFrame(fourth_soft_graph,columns=['L1','COUNT'])

fourth_soft_final_df = pd.concat([fourth_soft_df,fourth_soft_graph_df],axis=1)

# fourth_soft_final_df.to_sql(name=top_4_soft[3],con=engine,index=False,if_exists='replace')
# <--------------------------Fourth Highest no. of L2 occurence graph details completed-------------------------------->

# %%
L1_graph_df

# %%
first_soft_final_df

# %%
# coverting required sheet in df
converter_df = pd.read_csv('Updated Converter_7th Aug - Sheet1.csv')
universal_df = pd.read_csv('Updated Cush Sheet as on 17 August - Updated Cush.csv')


# creating column names for the integration
Integration_column = []
no_of_column_not_containing_integration = int(input('Enter a number of column which is not containing Integrations: '))
for i in range(1,len(raw_df.columns)-(no_of_column_not_containing_integration-1)):
    Integration_column.append('Integration '+str(i))
# pp.pprint(Integration_column)


other_column = []
for i in range(no_of_column_not_containing_integration):
    col = input('Enter name of column '+ str(i+1)+' which are not containing integrations: ')
    other_column.append(col)
pp.pprint(other_column)

new_cols = other_column + Integration_column
raw_df.columns = new_cols

# coverting only integration column of raw_df to dataframe
Integration_df = raw_df[Integration_column]
# pp.pprint(Integration_df)

dictionary = {'/':' ','\s+':' ',r'^\s+':'',r'\s+$':''}   # replace '/' with " ", '\s+' with " ", r'^\s+'->left strip,r'\s+$'->Right strip
Integration_df.replace(dictionary,regex=True,inplace=True)

# replacing null cells with space
Integration_df.replace('','zzz',inplace=True)


# making a list of integration available in the raw_df
Integration_list = []
for i in range(len(Integration_df.index)):
    Integration_list += Integration_df.values[i].tolist()


# making a new list for distinct integrations available in AB_df
unique_integration_set = set(Integration_list)
old_unique_integration_list = list(unique_integration_set)
# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))
integration_list_lower = []
for i in range(len(old_unique_integration_list)):
    integration_list_lower.append(str(old_unique_integration_list[i]).lower().replace(' ',''))

unique_integration_list_lower = list(set(integration_list_lower))
# print(len(unique_integration_list_lower))

unique_integration_dict = {}
for key in unique_integration_list_lower:
    for value in old_unique_integration_list:
        if key == str(value).lower().replace(' ',''):
            unique_integration_dict[key] = value 
            del key
            break
# print(len(unique_integration_dict))

unique_integration_list = []

for value in unique_integration_dict.values():
    unique_integration_list.append(str(value))

# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))


# removiung nan from unique_integration_list
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'nan']
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'zzz']

print('unique integration list: '+ str(len(unique_integration_list)))

# list Software name available in converter df
Software_Name = converter_df['Software Name'].tolist()
# pp.pprint(Software_Name)

# list Actual spelling of Software name available in converter df
Actual_Spelling = converter_df['Actual Spelling'].tolist()
# pp.pprint(Actual_Spelling)


# making dictionary to map Software Name to their Actual Spelling
converter_dictionary = {}
for key in Software_Name:
    for value in Actual_Spelling:
        converter_dictionary[key] = value
        Actual_Spelling.remove(value)
        break
# pp.pprint(converter_dictionary)


# making list of Integration available in universal sheet
universal_integration_list = universal_df['Software Name'].tolist()
unique_universal_integration_list = list(set(universal_integration_list))
# pp.pprint(len(sorted(universal_integration_list)))


# making dictionary for unique universal integration list
universal_integration_dictionary = {}
for key in unique_universal_integration_list:
    for value in unique_universal_integration_list:
        if key == value:
            universal_integration_dictionary[key] = value
            break
# pp.pprint(universal_integration_dictionary)


# merging universal integration dictionary and converter dictionary
universal_integration_dictionary.update(converter_dictionary)
# print('universal integration dictionary: '+str(len(universal_integration_dictionary)))


found_integration_dct = {}
# step 1
# In this step elements of unique_integration_list are searched in universal_integration_list keys
# and if element of unique_integration_list found in universal_integration_dictionary
# then this element is changed to its standard value using universal_integration_dictionary
# values and updated in the AB_df
found_integration_list_in_step1 = []
found_integration_dct_in_step1 = {}
not_found_integration_in_step1 = []
for i in range(len(unique_integration_list)):
    for key,value in universal_integration_dictionary.items():
        if str(key).casefold() == str(unique_integration_list[i]).casefold():
            Integration_df.replace(to_replace=unique_integration_list[i], value=value,inplace=True)
            found_integration_list_in_step1.append(unique_integration_list[i])
            found_integration_dct_in_step1[key] = value
            break
    else:
        not_found_integration_in_step1.append(unique_integration_list[i])
found_integration_dct.update(found_integration_dct_in_step1)

# print('Integration found in step1: ' + str(len(found_integration_list_in_step1)))
# print('Integration not found in step1: '+str(len(not_found_integration_in_step1)))
# print('found_integration_dct length after step 1: '+ str(len(found_integration_dct)))



# step 2 
# In this step space between integrations are removed and then convert all integration in lower case
# then this integration names are searched in the dictionary by converting all dictionary key and value
# in lower and replace space between integration name. one dictionary is made for the integrations which are found 
# which were not found in previous step named dct. After this search the not found integration in previous step and 
# search it in dct, and change it with value available in dct.
found_integration_dct_in_step2 = {}
found_integration_in_step2 = []

for i in range(len(not_found_integration_in_step1)):
    for key,value in universal_integration_dictionary.items():
        if str(not_found_integration_in_step1[i]).casefold().replace(' ','') == str(key).casefold().replace(' ',''):
            found_integration_dct_in_step2[not_found_integration_in_step1[i]] = value
            found_integration_in_step2.append(not_found_integration_in_step1[i])
            break

not_found_integration_in_step2 = list(set(not_found_integration_in_step1)-set(found_integration_in_step2))
# print('not found integration after step 2: '+str(len(not_found_integration_in_step2)))

found_integration_dct.update(found_integration_dct_in_step2)
# print('found integration dct after step 2: '+str(len(found_integration_dct)))
# del found_integration_dct['zzz']       

# pp.pprint(dct)
# print('found integration in step 2 '+ str(len(found_integration_in_step2)))



for i in range(len(found_integration_in_step2)):
    for key,value in found_integration_dct_in_step2.items():
        if found_integration_in_step2[i].casefold().replace(' ','') == key.casefold().replace(' ',''):
            Integration_df.replace(to_replace=found_integration_in_step2[i],value=value, inplace=True)
            break




lol_Integration = Integration_df.values.tolist()   # give list of list available in integration column (row wise list)
list_Integration = []   

for i in range(len(lol_Integration)):
    for j in range(len(lol_Integration[i])):
        list_Integration.append(lol_Integration[i][j])

# now list_Integration contains list of integration available in Integration column

Integration_dct = {}

for i in list_Integration:
    Integration_dct[i] = Integration_dct.get(i,0)+1
# now Integration dct will contain software name as key and its occurence in list as value

if 'zzz' in Integration_dct:
    del Integration_dct['zzz']   # removing zzz key from dictionary

integrals_max_df = pd.DataFrame(Integration_dct.items(),columns=['Software','SUM of Integration Count'])

integrals_max_df = integrals_max_df.sort_values(by='SUM of Integration Count', ascending=False,ignore_index=True)

integrals_max_df.dropna(inplace=True)

Most_Popular_Integrations = integrals_max_df.iloc[0:11]
Most_Popular_Integrations[''] = 'Most Popular Integrations'

integrals_max_df = pd.concat([integrals_max_df,Most_Popular_Integrations],axis=1)

df = integrals_max_df['']
integrals_max_df.drop('',axis=1,inplace=True)
integrals_max_df.insert(3,'',df)

# %%
Integration_df

# %%
import sqlalchemy
import pandas as pd
import pymysql
import pprint

pp = pprint.PrettyPrinter()

engine = sqlalchemy.create_engine('mysql+pymysql://root:admin@localhost:3306/test')

raw_df = pd.read_sql('raw_data',engine)


# coverting required sheet in df
converter_df = pd.read_csv('Updated Converter_7th Aug - Sheet1.csv')
universal_df = pd.read_csv('Updated Cush Sheet as on 17 August - Updated Cush.csv')


# creating column names for the integration
Integration_column = []
no_of_column_not_containing_integration = int(input('Enter a number of column which is not containing Integrations: '))
for i in range(1,len(raw_df.columns)-(no_of_column_not_containing_integration-1)):
    Integration_column.append('Integration '+str(i))
# pp.pprint(Integration_column)


other_column = []
for i in range(no_of_column_not_containing_integration):
    col = input('Enter name of column '+ str(i+1)+' which are not containing integrations: ')
    other_column.append(col)
pp.pprint(other_column)

new_cols = other_column + Integration_column
raw_df.columns = new_cols

# coverting only integration column of raw_df to dataframe
Integration_df = raw_df[Integration_column]
# pp.pprint(Integration_df)

dictionary = {'/':' ','\s+':' ',r'^\s+':'',r'\s+$':''}   # replace '/' with " ", '\s+' with " ", r'^\s+'->left strip,r'\s+$'->Right strip
Integration_df.replace(dictionary,regex=True,inplace=True)

# replacing null cells with space
Integration_df.replace('','zzz',inplace=True)


# making a list of integration available in the raw_df
Integration_list = []
for i in range(len(Integration_df.index)):
    Integration_list += Integration_df.values[i].tolist()



# making a new list for distinct integrations available in AB_df
unique_integration_set = set(Integration_list)
unique_integration_list = list(unique_integration_set)
# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))

unique_integration_list = [i for i in unique_integration_list if str(i)!= 'nan']
print(len(unique_integration_list))


# list Software name available in converter df
Software_Name = converter_df['Software Name'].tolist()
# pp.pprint(Software_Name)

# list Actual spelling of Software name available in converter df
Actual_Spelling = converter_df['Actual Spelling'].tolist()
# pp.pprint(Actual_Spelling)


# making dictionary to map Software Name to their Actual Spelling
converter_dictionary = {}
for key in Software_Name:
    for value in Actual_Spelling:
        converter_dictionary[key] = value
        Actual_Spelling.remove(value)
        break

# pp.pprint(converter_dictionary)


# making list of Integration available in universal sheet
universal_integration_list = universal_df['Software Name'].tolist()
unique_universal_integration_list = list(set(universal_integration_list))
# pp.pprint(len(sorted(universal_integration_list)))


# making dictionary for unique universal integration list
universal_integration_dictionary = {}
for key in unique_universal_integration_list:
    for value in unique_universal_integration_list:
        if key == value:
            universal_integration_dictionary[key] = value
            break
# pp.pprint(universal_integration_dictionary)


# merging universal integration dictionary and converter dictionary
universal_integration_dictionary.update(converter_dictionary)
# print('universal integration dictionary: '+str(len(universal_integration_dictionary)))


found_integration_dct = {}
# step 1
# In this step elements of unique_integration_list are searched in universal_integration_list keys
# and if element of unique_integration_list found in universal_integration_dictionary
# then this element is changed to its standard value using universal_integration_dictionary
# values and updated in the AB_df
found_integration_list_in_step1 = []
found_integration_dct_in_step1 = {}
not_found_integration_in_step1 = []
for i in range(len(unique_integration_list)):
    for key,value in universal_integration_dictionary.items():
        if str(key).casefold() == str(unique_integration_list[i]).casefold():
            Integration_df.replace(to_replace=unique_integration_list[i], value=value,inplace=True)
            found_integration_list_in_step1.append(unique_integration_list[i])
            found_integration_dct_in_step1[key] = value
            break
    else:
        not_found_integration_in_step1.append(unique_integration_list[i])
found_integration_dct.update(found_integration_dct_in_step1)

# print('Integration found in step1: ' + str(len(found_integration_list_in_step1)))
# print('Integration not found in step1: '+str(len(not_found_integration_in_step1)))
# print('found_integration_dct length after step 1: '+ str(len(found_integration_dct)))



# step 2 
# In this step space between integrations are removed and then convert all integration in lower case
# then this integration names are searched in the dictionary by converting all dictionary key and value
# in lower and replace space between integration name. one dictionary is made for the integrations which are found 
# which were not found in previous step named dct. After this search the not found integration in previous step and 
# search it in dct, and change it with value available in dct.
found_integration_dct_in_step2 = {}
found_integration_in_step2 = []

for i in range(len(not_found_integration_in_step1)):
    for key,value in universal_integration_dictionary.items():
        if str(not_found_integration_in_step1[i]).casefold().replace(' ','') == str(key).casefold().replace(' ',''):
            found_integration_dct_in_step2[not_found_integration_in_step1[i]] = value
            found_integration_in_step2.append(not_found_integration_in_step1[i])
            break

not_found_integration_in_step2 = list(set(not_found_integration_in_step1)-set(found_integration_in_step2))
# print('not found integration after step 2: '+str(len(not_found_integration_in_step2)))

found_integration_dct.update(found_integration_dct_in_step2)
# print('found integration dct after step 2: '+str(len(found_integration_dct)))
# del found_integration_dct['zzz']       

# pp.pprint(dct)
# print('found integration in step 2 '+ str(len(found_integration_in_step2)))



for i in range(len(found_integration_in_step2)):
    for key,value in found_integration_dct_in_step2.items():
        if found_integration_in_step2[i].casefold().replace(' ','') == key.casefold().replace(' ',''):
            Integration_df.replace(to_replace=found_integration_in_step2[i],value=value, inplace=True)
            break


not_found_integration = not_found_integration_in_step2
for i in range(len(not_found_integration)):
    Integration_df.replace(not_found_integration[i],'zzz',inplace=True)

other_column_df = raw_df[other_column]
final_df = pd.concat([other_column_df,Integration_df],axis=1)



sn2an_df = pd.DataFrame(sorted(list(found_integration_dct.items())), columns=['Software Name','Actual Name'])
sn2an_notfound_df = pd.DataFrame(not_found_integration, columns=['Software Name'])

# %%
final_df

# %%
Integration_df = raw_df[Integration_column]
Integration_list = Integration_df.values.tolist()
Integrations = []
for i in range(len(Integration_list)):
    for j in range(len(Integration_list[i])):
        Integrations.append(Integration_list[i][j])

Integrations_lol = [[i] for i in Integrations]

# %%
Integrations_lol

# %%
# import sqlalchemy
import pandas as pd
# import pymysql
import pprint

pp = pprint.PrettyPrinter()

# engine = sqlalchemy.create_engine('mysql+pymysql://root:admin@localhost:3306/test')

raw_df = pd.read_excel('Raw Data_Sales Intelligence.xlsx')


# coverting required sheet in df
converter_df = pd.read_csv('Updated Converter_7th Aug - Sheet1.csv')
universal_df = pd.read_csv('Updated Cush Sheet as on 17 August - Updated Cush.csv')


# creating column names for the integration
Integration_column = []
no_of_column_not_containing_integration = int(input('Enter a number of column which is not containing Integrations: '))
for i in range(1,len(raw_df.columns)-(no_of_column_not_containing_integration-1)):
    Integration_column.append('Integration '+str(i))
# pp.pprint(Integration_column)


other_column = []
for i in range(no_of_column_not_containing_integration):
    col = input('Enter name of column '+ str(i+1)+' which are not containing integrations: ')
    other_column.append(col)
pp.pprint(other_column)

new_cols = other_column + Integration_column
raw_df.columns = new_cols

# coverting only integration column of raw_df to dataframe
Integration_df = raw_df[Integration_column]
# pp.pprint(Integration_df)

dictionary = {'/':' ','\s+':' ',r'^\s+':'',r'\s+$':''}   # replace '/' with " ", '\s+' with " ", r'^\s+'->left strip,r'\s+$'->Right strip
Integration_df.replace(dictionary,regex=True,inplace=True)

# replacing null cells with space
Integration_df.replace('','zzz',inplace=True)


# making a list of integration available in the raw_df
Integration_list = []
for i in range(len(Integration_df.index)):
    Integration_list += Integration_df.values[i].tolist()


# making a new list for distinct integrations available in AB_df
unique_integration_set = set(Integration_list)
old_unique_integration_list = list(unique_integration_set)
# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))
integration_list_lower = []
for i in range(len(old_unique_integration_list)):
    integration_list_lower.append(str(old_unique_integration_list[i]).lower().replace(' ',''))

unique_integration_list_lower = list(set(integration_list_lower))
# print(len(unique_integration_list_lower))

unique_integration_dict = {}
for key in unique_integration_list_lower:
    for value in old_unique_integration_list:
        if key == str(value).lower().replace(' ',''):
            unique_integration_dict[key] = value 
            del key
            break
# print(len(unique_integration_dict))

unique_integration_list = []

for value in unique_integration_dict.values():
    unique_integration_list.append(str(value))

# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))


# removiung nan from unique_integration_list
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'nan']
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'zzz']

print('unique integration list: '+ str(len(unique_integration_list)))

# list Software name available in converter df
Software_Name = converter_df['Software Name'].tolist()
# pp.pprint(Software_Name)

# list Actual spelling of Software name available in converter df
Actual_Spelling = converter_df['Actual Spelling'].tolist()
# pp.pprint(Actual_Spelling)


# making dictionary to map Software Name to their Actual Spelling
converter_dictionary = {}
for key in Software_Name:
    for value in Actual_Spelling:
        converter_dictionary[key] = value
        Actual_Spelling.remove(value)
        break
# pp.pprint(converter_dictionary)


# making list of Integration available in universal sheet
universal_integration_list = universal_df['Software Name'].tolist()
unique_universal_integration_list = list(set(universal_integration_list))
# pp.pprint(len(sorted(universal_integration_list)))


# making dictionary for unique universal integration list
universal_integration_dictionary = {}
for key in unique_universal_integration_list:
    for value in unique_universal_integration_list:
        if key == value:
            universal_integration_dictionary[key] = value
            break
# pp.pprint(universal_integration_dictionary)


# merging universal integration dictionary and converter dictionary
universal_integration_dictionary.update(converter_dictionary)
# print('universal integration dictionary: '+str(len(universal_integration_dictionary)))


found_integration_dct = {}
# step 1
# In this step elements of unique_integration_list are searched in universal_integration_list keys
# and if element of unique_integration_list found in universal_integration_dictionary
# then this element is changed to its standard value using universal_integration_dictionary
# values and updated in the AB_df
found_integration_list_in_step1 = []
found_integration_dct_in_step1 = {}
not_found_integration_in_step1 = []
for i in range(len(unique_integration_list)):
    for key,value in universal_integration_dictionary.items():
        if str(key).casefold() == str(unique_integration_list[i]).casefold():
            Integration_df.replace(to_replace=unique_integration_list[i], value=value,inplace=True)
            found_integration_list_in_step1.append(unique_integration_list[i])
            found_integration_dct_in_step1[key] = value
            break
    else:
        not_found_integration_in_step1.append(unique_integration_list[i])
found_integration_dct.update(found_integration_dct_in_step1)

# print('Integration found in step1: ' + str(len(found_integration_list_in_step1)))
# print('Integration not found in step1: '+str(len(not_found_integration_in_step1)))
# print('found_integration_dct length after step 1: '+ str(len(found_integration_dct)))



# step 2 
# In this step space between integrations are removed and then convert all integration in lower case
# then this integration names are searched in the dictionary by converting all dictionary key and value
# in lower and replace space between integration name. one dictionary is made for the integrations which are found 
# which were not found in previous step named dct. After this search the not found integration in previous step and 
# search it in dct, and change it with value available in dct.
found_integration_dct_in_step2 = {}
found_integration_in_step2 = []

for i in range(len(not_found_integration_in_step1)):
    for key,value in universal_integration_dictionary.items():
        if str(not_found_integration_in_step1[i]).casefold().replace(' ','') == str(key).casefold().replace(' ',''):
            found_integration_dct_in_step2[not_found_integration_in_step1[i]] = value
            found_integration_in_step2.append(not_found_integration_in_step1[i])
            break

not_found_integration_in_step2 = list(set(not_found_integration_in_step1)-set(found_integration_in_step2))
# print('not found integration after step 2: '+str(len(not_found_integration_in_step2)))

found_integration_dct.update(found_integration_dct_in_step2)
# print('found integration dct after step 2: '+str(len(found_integration_dct)))
# del found_integration_dct['zzz']       

# pp.pprint(dct)
# print('found integration in step 2 '+ str(len(found_integration_in_step2)))



for i in range(len(found_integration_in_step2)):
    for key,value in found_integration_dct_in_step2.items():
        if found_integration_in_step2[i].casefold().replace(' ','') == key.casefold().replace(' ',''):
            Integration_df.replace(to_replace=found_integration_in_step2[i],value=value, inplace=True)
            break

not_found_integration = not_found_integration_in_step2
for i in range(len(not_found_integration)):
    Integration_df.replace(not_found_integration[i],'zzz',inplace=True)


other_column_df = raw_df[other_column]
final_df = pd.concat([other_column_df,Integration_df],axis=1)
final_df.to_csv('cleaned.csv',index=False)


sn2an_df = pd.DataFrame(sorted(list(found_integration_dct.items())), columns=['Software Name','Actual Name'])
sn2an_notfound_df = pd.DataFrame(not_found_integration, columns=['Software Name'])



# Software to its Category mapping


# s2c = software to category list of lists
s2c = [list(i) for i in universal_df.itertuples(index=False)] # converted softwarename list available in to universal sheet into list of lists


# a new list made for found integration using software count dct
found_integration_list = []
for i in found_integration_dct.values():
    if i not in found_integration_list:
        found_integration_list.append(str(i).lower())

found_integration_list = [i for i in found_integration_list if str(i)!= 'zzz']  # remove 'zzz' if there any
# print('found_integration_list length: '+str(len(found_integration_list)))




# found integration list will convert into list of list
found_integration_lol = [[i] for i in found_integration_list] # found_integration_list is converted into list of list
pp.pprint(sorted(found_integration_lol))
# print(len(found_integration_lol))



# this code will map software name to its all available category using the Universal sheet(The Cush sheet)
for i in range(len(found_integration_lol)):
    for j in range(len(s2c)):
        if str(found_integration_lol[i][0]).casefold().replace(' ','') == str(s2c[j][0]).casefold().replace(' ',''):
            found_integration_lol[i].append(s2c[j][1])

            
pp.pprint(found_integration_lol)

s2c_df = pd.DataFrame(sorted(found_integration_lol),columns=None)   # convert mapped list(found_integration_lol) into dataframe

cat_cols = []
for i in range(len(s2c_df.columns)-1):
    cat_cols.append('Category '+str(i+1))

mapping_cols = ["software"] + cat_cols

s2c_df.columns = mapping_cols

s2c_df['count'] = s2c_df[cat_cols].count(axis=1)



s2c_df
# s2c_df.to_sql(name='software to category mapping',con=engine,index=False,if_exists='replace')

# %%
s2c_df.to_csv('map.csv')

# %%
import sqlalchemy
import pandas as pd
import pymysql
import pprint

pp = pprint.PrettyPrinter()

# engine = sqlalchemy.create_engine('mysql+pymysql://root:admin@localhost:3306/test')

raw_df = pd.read_excel('Raw Data_Sales Intelligence.xlsx')


# coverting required sheet in df
converter_df = pd.read_csv('Updated Converter_7th Aug - Sheet1.csv')
universal_df = pd.read_csv('Updated Cush Sheet as on 17 August - Updated Cush.csv')


# creating column names for the integration
Integration_column = []
no_of_column_not_containing_integration = int(input('Enter a number of column which is not containing Integrations: '))
for i in range(1,len(raw_df.columns)-(no_of_column_not_containing_integration-1)):
    Integration_column.append('Integration '+str(i))
# pp.pprint(Integration_column)


other_column = []
for i in range(no_of_column_not_containing_integration):
    col = input('Enter name of column '+ str(i+1)+' which are not containing integrations: ')
    other_column.append(col)
pp.pprint(other_column)

new_cols = other_column + Integration_column
raw_df.columns = new_cols

# coverting only integration column of raw_df to dataframe
Integration_df = raw_df[Integration_column]
# pp.pprint(Integration_df)

dictionary = {'/':' ','\s+':' ',r'^\s+':'',r'\s+$':''}   # replace '/' with " ", '\s+' with " ", r'^\s+'->left strip,r'\s+$'->Right strip
Integration_df.replace(dictionary,regex=True,inplace=True)

# replacing null cells with space
Integration_df.replace('','zzz',inplace=True)


# making a list of integration available in the raw_df
Integration_list = []
for i in range(len(Integration_df.index)):
    Integration_list += Integration_df.values[i].tolist()


# making a new list for distinct integrations available in AB_df
unique_integration_set = set(Integration_list)
old_unique_integration_list = list(unique_integration_set)
# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))
integration_list_lower = []
for i in range(len(old_unique_integration_list)):
    integration_list_lower.append(str(old_unique_integration_list[i]).lower().replace(' ',''))

unique_integration_list_lower = list(set(integration_list_lower))
# print(len(unique_integration_list_lower))

unique_integration_dict = {}
for key in unique_integration_list_lower:
    for value in old_unique_integration_list:
        if key == str(value).lower().replace(' ',''):
            unique_integration_dict[key] = value 
            del key
            break
# print(len(unique_integration_dict))

unique_integration_list = []

for value in unique_integration_dict.values():
    unique_integration_list.append(str(value))

# pp.pprint(unique_integration_list)
# print(len(unique_integration_list))


# removiung nan from unique_integration_list
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'nan']
unique_integration_list = [i for i in unique_integration_list if str(i)!= 'zzz']

print('unique integration list: '+ str(len(unique_integration_list)))

# list Software name available in converter df
Software_Name = converter_df['Software Name'].tolist()
# pp.pprint(Software_Name)

# list Actual spelling of Software name available in converter df
Actual_Spelling = converter_df['Actual Spelling'].tolist()
# pp.pprint(Actual_Spelling)


# making dictionary to map Software Name to their Actual Spelling
converter_dictionary = {}
for key in Software_Name:
    for value in Actual_Spelling:
        converter_dictionary[key] = value
        Actual_Spelling.remove(value)
        break
# pp.pprint(converter_dictionary)


# making list of Integration available in universal sheet
universal_integration_list = universal_df['Software Name'].tolist()
unique_universal_integration_list = list(set(universal_integration_list))
# pp.pprint(len(sorted(universal_integration_list)))


# making dictionary for unique universal integration list
universal_integration_dictionary = {}
for key in unique_universal_integration_list:
    for value in unique_universal_integration_list:
        if key == value:
            universal_integration_dictionary[key] = value
            break
# pp.pprint(universal_integration_dictionary)


# merging universal integration dictionary and converter dictionary
universal_integration_dictionary.update(converter_dictionary)
# print('universal integration dictionary: '+str(len(universal_integration_dictionary)))


found_integration_dct = {}
# step 1
# In this step elements of unique_integration_list are searched in universal_integration_list keys
# and if element of unique_integration_list found in universal_integration_dictionary
# then this element is changed to its standard value using universal_integration_dictionary
# values and updated in the AB_df
found_integration_list_in_step1 = []
found_integration_dct_in_step1 = {}
not_found_integration_in_step1 = []
for i in range(len(unique_integration_list)):
    for key,value in universal_integration_dictionary.items():
        if str(key).casefold() == str(unique_integration_list[i]).casefold():
            Integration_df.replace(to_replace=unique_integration_list[i], value=value,inplace=True)
            found_integration_list_in_step1.append(unique_integration_list[i])
            found_integration_dct_in_step1[key] = value
            break
    else:
        not_found_integration_in_step1.append(unique_integration_list[i])
found_integration_dct.update(found_integration_dct_in_step1)

# print('Integration found in step1: ' + str(len(found_integration_list_in_step1)))
# print('Integration not found in step1: '+str(len(not_found_integration_in_step1)))
# print('found_integration_dct length after step 1: '+ str(len(found_integration_dct)))



# step 2 
# In this step space between integrations are removed and then convert all integration in lower case
# then this integration names are searched in the dictionary by converting all dictionary key and value
# in lower and replace space between integration name. one dictionary is made for the integrations which are found 
# which were not found in previous step named dct. After this search the not found integration in previous step and 
# search it in dct, and change it with value available in dct.
found_integration_dct_in_step2 = {}
found_integration_in_step2 = []

for i in range(len(not_found_integration_in_step1)):
    for key,value in universal_integration_dictionary.items():
        if str(not_found_integration_in_step1[i]).casefold().replace(' ','') == str(key).casefold().replace(' ',''):
            found_integration_dct_in_step2[not_found_integration_in_step1[i]] = value
            found_integration_in_step2.append(not_found_integration_in_step1[i])
            break

not_found_integration_in_step2 = list(set(not_found_integration_in_step1)-set(found_integration_in_step2))
# print('not found integration after step 2: '+str(len(not_found_integration_in_step2)))

found_integration_dct.update(found_integration_dct_in_step2)
# print('found integration dct after step 2: '+str(len(found_integration_dct)))
# del found_integration_dct['zzz']       

# pp.pprint(dct)
# print('found integration in step 2 '+ str(len(found_integration_in_step2)))



for i in range(len(found_integration_in_step2)):
    for key,value in found_integration_dct_in_step2.items():
        if found_integration_in_step2[i].casefold().replace(' ','') == key.casefold().replace(' ',''):
            Integration_df.replace(to_replace=found_integration_in_step2[i],value=value, inplace=True)
            break

not_found_integration = not_found_integration_in_step2
for i in range(len(not_found_integration)):
    Integration_df.replace(not_found_integration[i],'zzz',inplace=True)


other_column_df = raw_df[other_column]
final_df = pd.concat([other_column_df,Integration_df],axis=1)
final_df.to_csv('cleaned.csv',index=False)


sn2an_df = pd.DataFrame(sorted(list(found_integration_dct.items())), columns=['Software Name','Actual Name'])
sn2an_notfound_df = pd.DataFrame(not_found_integration, columns=['Software Name'])



# Software to its Category mapping


# s2c = software to category list of lists
s2c = [list(i) for i in universal_df.itertuples(index=False)] # converted softwarename list available in to universal sheet into list of lists


# a new list made for found integration using software count dct
found_integration_list = []
for i in found_integration_dct.values():
    if i not in found_integration_list:
        found_integration_list.append(str(i).lower())

found_integration_list = [i for i in found_integration_list if str(i)!= 'zzz']  # remove 'zzz' if there any
# print('found_integration_list length: '+str(len(found_integration_list)))




# found integration list will convert into list of list
found_integration_lol = [[i] for i in found_integration_list] # found_integration_list is converted into list of list
pp.pprint(sorted(found_integration_lol))
# print(len(found_integration_lol))



# this code will map software name to its all available category using the Universal sheet(The Cush sheet)
for i in range(len(found_integration_lol)):
    for j in range(len(s2c)):
        if str(found_integration_lol[i][0]).casefold().replace(' ','') == str(s2c[j][0]).casefold().replace(' ',''):
            found_integration_lol[i].append(s2c[j][1])

            
pp.pprint(found_integration_lol)

s2c_df = pd.DataFrame(sorted(found_integration_lol),columns=None)   # convert mapped list(found_integration_lol) into dataframe

cat_cols = []
for i in range(len(s2c_df.columns)-1):
    cat_cols.append('Category '+str(i+1))

mapping_cols = ["software"] + cat_cols

s2c_df.columns = mapping_cols

s2c_df['count'] = s2c_df[cat_cols].count(axis=1)


# Integration_df = raw_df[Integration_column]
Integration_list = Integration_df.values.tolist()
Integrations = []
for i in range(len(Integration_list)):
    for j in range(len(Integration_list[i])):
        Integrations.append(Integration_list[i][j])

Integrations_lol = [[i] for i in Integrations]

for i in range(len(Integrations_lol)):
    for j in range(len(s2c)):
        if str(Integrations_lol[i][0]).lower().replace(' ','') == str(s2c[j][0]).lower().replace(' ',''):
            Integrations_lol[i].append(s2c[j][1])

s2c_list = Integrations_lol
s2c_list = [[str(s2c_list[i][j]).split(' - ',1) for j in range(len(s2c_list[i]))]for i in range(len(s2c_list))]            

for i in range(len(s2c_list)):
    for j in range(len(s2c_list[i])):
        if len(s2c_list[i][j])>1:
            s2c_list[i][j].remove(s2c_list[i][j][1])

L1_dct = {}
for i in range(len(s2c_list)):
    for j in range(1,len(s2c_list[i])):
        L1_dct[s2c_list[i][j][0]] = L1_dct.get(s2c_list[i][j][0],0)+1

L1_occurence_lot = [(k,v) for k,v in L1_dct.items()]
for i in L1_occurence_lot:
    if i[0] == 'nan':
        L1_occurence_lot.remove(i)
    if i[0] == 'Error':
        L1_occurence_lot.remove(i)
    if i[0] == 'Error -':
        L1_occurence_lot.remove(i)

L1_lol = []
for i in L1_dct:
    L1_lol.append([i])

L1 = L1_lol

for i in range(len(L1_lol)):
    for j in range(len(s2c_list)):
        for k in range(1,len(s2c_list[j])):
            if L1_lol[i][0] == s2c_list[j][k][0]:
                L1_lol[i].append(s2c_list[j][0][0])

List_software_occurence = []
temp_dct = {}
for i in range(len(L1_lol)):
    for j in range(len(L1_lol[i])):
        temp_dct[L1_lol[i][j]] = temp_dct.get(L1_lol[i][j],0)+1
    List_software_occurence.append(dict(temp_dct))
    temp_dct.clear()

int_occurence_lot = []
for i in range(len(List_software_occurence)):
    int_occurence_lot.append(sorted([(k,v) for k,v in List_software_occurence[i].items()],key = lambda x:x[1],reverse=True))


for i in range(len(L1)):
    for j in range(len(int_occurence_lot)):
        for k in range(len(int_occurence_lot[j])):
            if L1[i][0] == int_occurence_lot[j][k][0]:
                L1[i].append(int_occurence_lot[j])

for i in range(len(L1)):
    while (len(L1[i]))!=2:
        for k,j in enumerate(L1[i]):    
            if k == 0:
                continue
            elif k == len(L1[i])-1:
                continue
            else:
                L1[i].remove(j)

for i in range(len(L1)):
    for j in range(1,len(L1[i])):
        for k in L1[i][j]:
            L1[i].append(k)
        L1[i][1].clear()

L1_df = pd.DataFrame(L1)
L1_df.drop(L1_df.iloc[:,[1]],axis=1,inplace=True)

L1_df_list = L1_df.values.tolist()
L1_df_list = [[j for j in i if str(j) != 'None']for i in L1_df_list]

L1_cat = []
for i in range(len(L1_df_list)):
    L1_cat.append([L1_df_list[i][0]])                                                                    

s=0
for i in range(len(L1_cat)):
    for j in range(len(L1_df_list)):
        if L1_cat[i][0] == L1_df_list[j][0]:
            for k in range(1,len(L1_df_list[j])):
                s = s + L1_df_list[j][k][1]
    L1_cat[i].append(s)
    s=0
                
L1_cat_df = pd.DataFrame(L1_cat)
L1_cat_df.columns = ['L1','COUNT of L1']
L1_cat_df.sort_values(by='COUNT of L1',ascending=False,ignore_index=True)

L1_df_list = [[[j]for j in i]for i in L1_df_list]

for i in range(len(L1_df_list)):
    for j in range(len(L1_df_list[i])):
        if j == 0:
            continue
        else:
            L1_df_list[i][j].insert(0,L1_df_list[i][0][0])

new_L1_df_list = []
for i in range(len(L1_df_list)):
    for j in range(len(L1_df_list[i])):
        new_L1_df_list.append(L1_df_list[i][j])

for i in range(len(new_L1_df_list)):
    if len(new_L1_df_list[i])>1:
        new_L1_df_list[i].append(new_L1_df_list[i][1][0])
        new_L1_df_list[i].append(new_L1_df_list[i][1][1])

for i in new_L1_df_list:
    if len(i)==1:
        new_L1_df_list.remove(i)

L1_soft_count_df = pd.DataFrame(new_L1_df_list)
L1_soft_count_df.drop(L1_soft_count_df.iloc[:,[1]],axis=1,inplace=True)
L1_soft_count_df.columns = ['L1','Software Name','Count']


Functional_area_leader_df = pd.concat([L1_cat_df,L1_soft_count_df],axis=1)
Functional_area_leader_df
# Out:
# Enter a number of column which is not containing Integrations: 7
# Enter name of column 1 which are not containing integrations: Title
# Enter name of column 2 which are not containing integrations: Review URL
# Enter name of column 3 which are not containing integrations: G2 Score
# Enter name of column 4 which are not containing integrations: Description
# Enter name of column 5 which are not containing integrations: Reviews
# Enter name of column 6 which are not containing integrations: Comments
# Enter name of column 7 which are not containing integrations: Website
# ['Title',
#  'Review URL',
#  'G2 Score',
#  'Description',
#  'Reviews',
#  'Comments',
#  'Website']
# C:\Users\ronak\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:4373: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# unique integration list: 492
# [['.net core'],
#  ['366 degrees'],
#  ['6sense'],
#  ['8x8'],
#  ['act-on'],
#  ['activecampaign'],
#  ['activedemand'],
#  ['adbeat'],
#  ['adobe analytics'],
#  ['adobe audience manager'],
#  ['adobe core services'],
#  ['adobe sign'],
#  ['adobe target'],
#  ['airtable'],
#  ['altify'],
#  ['amazon connect'],
#  ['amazon redshift'],
#  ['amazon s3 csv'],
#  ['amocrm'],
#  ['amplitude'],
#  ['angellist'],
#  ['appsflyer'],
#  ['ark for exchange server'],
#  ['asana'],
#  ['athena'],
#  ['atom'],
#  ['automate.io'],
#  ['aweber'],
#  ['base'],
#  ['batchbook'],
#  ['better proposals'],
#  ['bigcommerce'],
#  ['bigquery'],
#  ['bitrix24'],
#  ['bmi'],
#  ['box'],
#  ['brex'],
#  ['buffer'],
#  ['calendly'],
#  ['calidore'],
#  ['capsule'],
#  ['chameleon'],
#  ['chartio'],
#  ['choozle'],
#  ['chrome'],
#  ['cipher'],
#  ['circleloop'],
#  ['cisco webex meetings'],
#  ['citrix podio'],
#  ['citus data'],
#  ['clari'],
#  ['clearbit'],
#  ['clickdesk'],
#  ['clickfunnels'],
#  ['close'],
#  ['clubhouse'],
#  ['comscore'],
#  ['connectwise sell'],
#  ['constant contact'],
#  ['copper'],
#  ['crm'],
#  ['crunchbase'],
#  ['crystal'],
#  ['cvent'],
#  ['databricks'],
#  ['datalytyx'],
#  ['datananas'],
#  ['datanyze'],
#  ['datanyze insider'],
#  ['dataproc'],
#  ['datatron'],
#  ['ddi'],
#  ['dealsignal'],
#  ['demand base'],
#  ['desk'],
#  ['dialpad talk'],
#  ['discoverorg'],
#  ['dmsi'],
#  ['docusign'],
#  ['dotscience'],
#  ['doubleclick manager'],
#  ['drift'],
#  ['drip'],
#  ['dropbox'],
#  ['dsi'],
#  ['edocr'],
#  ['elan'],
#  ['elastic mapreduce'],
#  ['enavate'],
#  ['engagio'],
#  ['ensighten'],
#  ['entelo'],
#  ['epicor erp'],
#  ['eventbrite'],
#  ['evernote'],
#  ['everstring'],
#  ['exchequer'],
#  ['facebook'],
#  ['facebook ads'],
#  ['fb messenger'],
#  ['five9'],
#  ['formstack'],
#  ['formstack documents'],
#  ['freshbooks'],
#  ['freshsales'],
#  ['funnelflare'],
#  ['g suite'],
#  ['gainsight'],
#  ['gartner'],
#  ['getaccept'],
#  ['gmail'],
#  ['google ads'],
#  ['google analytics'],
#  ['google analytics 360'],
#  ['google audience center 360'],
#  ['google calendar'],
#  ['google cloud functions'],
#  ['google data studio'],
#  ['google display & video 360'],
#  ['google drive'],
#  ['google hangouts chat'],
#  ['google maps api'],
#  ['google marketing platform'],
#  ['google search console'],
#  ['google sheets'],
#  ['gotomeeting'],
#  ['gototraining'],
#  ['gotowebinar'],
#  ['groove'],
#  ['growbots'],
#  ['grubhub'],
#  ['gumgum'],
#  ['harvest'],
#  ['hd insight'],
#  ['hellosign'],
#  ['heroku'],
#  ['highrise'],
#  ['highspot'],
#  ['hipchat'],
#  ['hired'],
#  ['hoiio'],
#  ['hubspot marketing hub'],
#  ['hubspot sales hub'],
#  ['hull'],
#  ['hunter'],
#  ['icontact'],
#  ['ifs alliance'],
#  ['ihookit'],
#  ['import2'],
#  ['ininbox'],
#  ['insightly crm'],
#  ['insightsquared'],
#  ['intact'],
#  ['integrate'],
#  ['intercom'],
#  ['intercom.io'],
#  ['intuit'],
#  ['ispot.tv'],
#  ['jira'],
#  ['karmak'],
#  ['keap (formerly infusionsoft)'],
#  ['keen.io'],
#  ['keeptruckin'],
#  ['kepion'],
#  ['kerridge'],
#  ['kontentino'],
#  ['lattice'],
#  ['lead squared'],
#  ['leaderboarded'],
#  ['leadspace'],
#  ['leanplum'],
#  ['less annoying crm'],
#  ['lime'],
#  ['linkedin premium'],
#  ['linkedin sales navigator'],
#  ['liveramp'],
#  ['localytics'],
#  ['locus'],
#  ['lucidchart'],
#  ['lusha'],
#  ['mace systems'],
#  ['mad mimi'],
#  ['magento open source'],
#  ['maghub'],
#  ['maginus'],
#  ['mailchimp'],
#  ['mailgun'],
#  ['mailshake'],
#  ['manzama'],
#  ['marketo'],
#  ['matomo'],
#  ['maximizer crm'],
#  ['media analytics'],
#  ['membrain'],
#  ['merlin'],
#  ['microsoft bi'],
#  ['microsoft dynamics 365 sales'],
#  ['microsoft excel'],
#  ['microsoft office 365'],
#  ['microsoft onedrive for business'],
#  ['microsoft outlook'],
#  ['microsoft power bi desktop'],
#  ['microsoft sql'],
#  ['microsoft teams'],
#  ['mitel revolution'],
#  ['mixmax'],
#  ['mixpanel'],
#  ['mobilise'],
#  ['modata'],
#  ['moneyguidepro'],
#  ['mopub'],
#  ['mysql'],
#  ['netsuite'],
#  ['nimble'],
#  ['nmbrs'],
#  ['nutshell'],
#  ['office 365'],
#  ['ogl'],
#  ['okta'],
#  ['one click politics'],
#  ['openprise'],
#  ['opensense'],
#  ['optimizely'],
#  ['oracle cx '],
#  ['oracle ebs'],
#  ['oracle eloqua'],
#  ['oracle engagement cloud'],
#  ['oracle peoplesoft'],
#  ['orderwise'],
#  ['outreach'],
#  ['outreach.io'],
#  ['pandadoc'],
#  ['pardot'],
#  ['pathmatics'],
#  ['pegasus'],
#  ['persistiq'],
#  ['piesync'],
#  ['ping identity'],
#  ['pipedrive'],
#  ['pipeline deals'],
#  ['plaid'],
#  ['ponto'],
#  ['practifi'],
#  ['primaerp'],
#  ['procore'],
#  ['product hunt'],
#  ['prospect.io'],
#  ['qubole'],
#  ['quickbooks online'],
#  ['rchilli'],
#  ['recruitee'],
#  ['recurly'],
#  ['relpro'],
#  ['reply'],
#  ['rightsignature'],
#  ['ringcentral office'],
#  ['rollworks'],
#  ['saasoptics'],
#  ['sage act'],
#  ['sage intacct'],
#  ['sales logix'],
#  ['salesflare'],
#  ['salesforce crm'],
#  ['salesforce iq'],
#  ['salesforce marketing cloud consulting services'],
#  ['salesforce service cloud'],
#  ['salesintel'],
#  ['salesloft'],
#  ['salesscreen'],
#  ['sap erp'],
#  ['sapling'],
#  ['scheduleonce'],
#  ['segment'],
#  ['seismic'],
#  ['sendpulse'],
#  ['sensor tower'],
#  ['sharepoint azure ad connect'],
#  ['sharp-ax'],
#  ['sharpspring'],
#  ['shopify'],
#  ['signal hq'],
#  ['sitecore'],
#  ['skuid'],
#  ['slack'],
#  ['smartsheet'],
#  ['snowflake'],
#  ['socialbro'],
#  ['solidworks'],
#  ['sonar'],
#  ['splash'],
#  ['split'],
#  ['spring ml'],
#  ['statsocial'],
#  ['stripe payments'],
#  ['sugar sell'],
#  ['super office'],
#  ['syspro'],
#  ['tact'],
#  ['talkdesk'],
#  ['taptica'],
#  ['teamleader'],
#  ['teradata'],
#  ['terminus'],
#  ['think'],
#  ['thoughtspot'],
#  ['tikit'],
#  ['time'],
#  ['toutapp'],
#  ['tray.io'],
#  ['trello'],
#  ['triblio'],
#  ['trinet'],
#  ['trueinfluence'],
#  ['truly'],
#  ['twilio sendgrid email api'],
#  ['twitter'],
#  ['twitter ads'],
#  ['typeform'],
#  ['uberflip'],
#  ['udemy'],
#  ['upsales'],
#  ['urban airship'],
#  ['vidyard'],
#  ['voilanorbert'],
#  ['volusion'],
#  ['vtiger'],
#  ['vuture'],
#  ['webcrm'],
#  ['webjaguar'],
#  ['whatfix'],
#  ['wilson allen'],
#  ['woocommerce'],
#  ['woodpecker.co'],
#  ['wordpress.com'],
#  ['workday'],
#  ['wufoo'],
#  ['xero'],
#  ['xing events'],
#  ['yelp for business'],
#  ['yesware'],
#  ['zapier'],
#  ['zendesk sell'],
#  ['zendesk support'],
#  ['zinnov'],
#  ['zoho crm'],
#  ['zoom'],
#  ['zoominfo powered by discoverorg']]
# [['angellist', 'HR Software - Talent Management Software'],
#  ['calendly',
#   'Office Software - Marketplace Apps',
#   'HR Software - Talent Management Software',
#   'Office Software - Marketplace Apps',
#   'HR Software - Talent Management Software'],
#  ['xing events',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software'],
#  ['elastic mapreduce', 'Analytics Software - Business Intelligence Software'],
#  ['mitel revolution',
#   'Office Software - Emergency Notification Software',
#   'Office Software - Emergency Notification Software',
#   'Office Software - Emergency Notification Software',
#   'Office Software - Emergency Notification Software'],
#  ['terminus', 'Error -'],
#  ['magento open source',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software'],
#  ['ddi', 'ERP Software - Project, Portfolio & Program Management Software'],
#  ['enavate', 'Error -'],
#  ['microsoft office 365', 'Office Software - Office Suites Software'],
#  ['crunchbase',
#   'IT Infrastructure Software - Data Exchange Software',
#   'Marketing Software - Market Intelligence Software',
#   'Sales - Sales Intelligence Software'],
#  ['lusha',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Intelligence Software'],
#  ['wufoo',
#   'Content Management Systems - Online Form Builder Software',
#   'Office Software - Marketplace Apps',
#   'Content Management Systems - Online Form Builder Software',
#   'Content Management Systems - Online Form Builder Software',
#   'Office Software - Marketplace Apps',
#   'Content Management Systems - Online Form Builder Software'],
#  ['chrome', 'Office Software - Browser Software'],
#  ['microsoft power bi desktop',
#   'Analytics Software - Analytics Platform Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Analytics Platform Software',
#   'Analytics Software - Analytics Platform Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Analytics Platform Software'],
#  ['datalytyx',
#   'Artificial Intelligence Software - Data Science & Machine Learning '
#   'Platforms'],
#  ['hull',
#   'IT Infrastructure Software - Data Integration Software',
#   'Marketing Software - Customer Data Platform (CDP) Software'],
#  ['insightsquared',
#   'Analytics Software - Analytics Platform Software',
#   'Sales - Sales Analytics'],
#  ['think', 'ERP Software - Accounting & Finance Software'],
#  ['outreach.io', 'Sales - Email software'],
#  ['ark for exchange server',
#   'Security Software - Other IT Security Software',
#   'Security Software - Other IT Security Software',
#   'Security Software - Other IT Security Software',
#   'Security Software - Other IT Security Software'],
#  ['tray.io', 'IT Infrastructure Software - Data Integration Software'],
#  ['rightsignature', 'Sales - E-Signature Software'],
#  ['vuture',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Marketing Analytics Software'],
#  ['doubleclick manager',
#   'Digital Advertising Platforms - Publisher Ad Management Software'],
#  ['locus', 'Supply Chain & Logistics Software - Shipping Software'],
#  ['teamleader',
#   'Sales - CRM Software',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Project, Portfolio & Program Management Software'],
#  ['toutapp',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['epicor erp',
#   'IT Management Software - Process Automation Software',
#   'ERP Software - Mixed Mode ERP Software',
#   'IT Management Software - Process Automation Software',
#   'ERP Software - Mixed Mode ERP Software',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Discrete ERP Software',
#   'ERP Software - ERP Systems',
#   'ERP Software - Mixed Mode ERP Software',
#   'ERP Software - Process ERP Software'],
#  ['qubole',
#   'Artificial Intelligence Software - Data Science & Machine Learning '
#   'Platforms',
#   'IT Infrastructure Software - Database Software',
#   'IT Infrastructure Software - Database Software',
#   'IT Infrastructure Software - Data Integration Software'],
#  ['adobe sign',
#   'Sales - E-Signature Software',
#   'Sales - E-Signature Software',
#   'Sales - E-Signature Software',
#   'Sales - E-Signature Software'],
#  ['segment',
#   'Data Privacy Software - Consent Management Platform Software',
#   'Data Privacy Software - Data Privacy Management Software',
#   'Data Privacy Software - Data Subject Access Request (DSAR) Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT Management Software - Data Governance Software',
#   'Marketing Software - Customer Data Platform (CDP) Software',
#   'Data Privacy Sotware - Consent Management Platform Software',
#   'Data Privacy Sotware - Data Privacy Management Software',
#   'Data Privacy Sotware - Data Subject Access Request (DSAR) Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT Management Software - Data Governance Software',
#   'Marketing Software - Customer Data Platform (CDP) Software'],
#  ['wordpress.com',
#   'Content Management Systems - Website Builder Software',
#   'Content Management Systems - Website Builder Software',
#   'Content Management Systems - Website Builder Software',
#   'Content Management Systems - Website Builder Software'],
#  ['woodpecker.co',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['ihookit', 'IT Software - Analytics and Valuation Platform'],
#  ['heroku', 'Development Software - Cloud Platform as a Service Software'],
#  ['reply',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['whatfix',
#   'Collaboration & Productivity Software - Digital Adoption Platform Software',
#   'Customer Service Software - Customer Self-Service Software'],
#  ['salesforce marketing cloud consulting services',
#   'Marketing software - Other Marketing Services Providers'],
#  ['twitter ads',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software'],
#  ['media analytics', 'Marketing Software - Content Marketing Software'],
#  ['engagio',
#   'Marketing Software - account-based and lead-based Marketing Software',
#   'Marketing Software - account-based and lead-based Marketing Software'],
#  ['kontentino', 'Marketing Software - Social Media Marketing Software'],
#  ['socialbro', 'Marketing Software - Social Media Marketing Software'],
#  ['salesintel', 'Sales - Sales Intelligence Software'],
#  ['leaderboarded', 'Error - '],
#  ['sales logix', 'Sales - CRM Software'],
#  ['grubhub', 'B2B Marketplace Platforms - On-Demand Delivery Software'],
#  ['sharepoint azure ad connect',
#   'Collaboration & Productivity Software - Other Collaboration Software'],
#  ['hired',
#   'HR Software - Staffing Software',
#   'HR Software - Talent Management Software',
#   'HR Software - Talent Management Software',
#   'HR Software - Talent Management Software'],
#  ['prospect.io',
#   'Office Software - Email Verification Software',
#   'Marketing Software - Email Marketing Software'],
#  ['mixmax',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['tikit', 'Sales - Online Ticketing Software'],
#  ['clickdesk',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Live Chat Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Live Chat Software'],
#  ['mad mimi',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Email Marketing Software'],
#  ['integrate', 'Error -', 'Error -', 'Error -'],
#  ['microsoft sql',
#   'Security Software - Data Security Software',
#   'IT Infrastructure Software - Database Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT infrastructure Software - Database Software',
#   'Security Software - Data Security Software',
#   'IT Infrastructure Software - Database Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT infrastructure Software - Database Software'],
#  ['capsule', 'Sales - CRM Software', 'Sales - CRM Software'],
#  ['mobilise', 'ERP Software - Cloud based ERP Software'],
#  ['lime',
#   'Sales - CRM Software',
#   'Governance, Risk & Compliance Software - IT Risk Management Software'],
#  ['salesflare', 'Sales - CRM Software', 'Sales - Other Sales'],
#  ['choozle',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software'],
#  ['sharp-ax', 'IT - stock control software'],
#  ['zinnov', 'IT - Computer Software'],
#  ['skuid', 'Development Software - Application Development Software'],
#  ['piesync',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT infrastructure Software - Data Integration Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT Infrastructure Software - Data Integration Software',
#   'IT infrastructure Software - Data Integration Software',
#   'IT Infrastructure Software - Data Integration Software'],
#  ['persistiq',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['solidworks', 'CAD & PLM Softwares - CAD Software'],
#  ['mailgun',
#   'Office Software - Email Verification Software',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Transactional Email Software',
#   'Office Software - Email Verification Software',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Transactional Email Software'],
#  ['gartner', 'Marketing Software - Technology Research Services'],
#  ['dsi',
#   'Supply Chain & Logistics Software - Supply Chain Management Software'],
#  ['intuit', 'Analytics Software - Other Analytics Software'],
#  ['google maps api',
#   'CAD & PLM Softwares - GIS Software',
#   'AD & PLM Software - GIS Software',
#   'CAD & PLM Softwares - GIS Software',
#   'AD & PLM Software - GIS Software'],
#  ['lead squared', 'Sales - CRM Software'],
#  ['merlin', 'Artificial Intelligence Software - Deep Learning Software'],
#  ['salesscreen',
#   'Sales - Sales Gamification Software',
#   'Sales - Sales Acceleration Software'],
#  ['atom',
#   'Development Software - Editor Software',
#   'IoT Management Software - IoT Analytics Software'],
#  ['highspot', 'Sales - Sales Acceleration Software'],
#  ['upsales',
#   'Upsales Sales and Marketing Platform',
#   'Upsales Sales and Marketing Platform'],
#  ['zendesk support',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Customer Service Software - Customer Self-Service Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Social Customer Service Software',
#   'IT Management Software - IT Service Management Tools',
#   'Customer Service Software - HelpDesk Software',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Customer Service Software - Customer Self-Service Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Social Customer Service Software',
#   'IT Management Software - IT Service Management Tools',
#   'Customer Service Software - Help Desk Software'],
#  ['dmsi', 'ERP Software - Accounting & Finance Software'],
#  ['microsoft bi', 'IT Software - Application Software'],
#  ['leanplum',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Mobile Marketing Software',
#   'Marketing Software - Push Notification Software'],
#  ['gainsight',
#   'Customer Service Software - Customer Success Software',
#   'Customer Service Software - Experience Management Software',
#   'Sales - Customer Revenue Optimisation Software'],
#  ['practifi', 'Finance - Business Management Software'],
#  ['databricks',
#   'IT Infrastructure Software - Database Software',
#   'IT Infrastructure Software - Data Warehouse Software'],
#  ['truly',
#   'Collaboration & Productivity Software - VoIP Providers',
#   'Customer Service Software - Contact Center Software',
#   'Marketing Software - Inbound Call Tracking Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['yesware',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Intelligence Software'],
#  ['datanyze insider',
#   'Artificial Intelligence Software - Data Science & Machine Learning '
#   'Platforms'],
#  ['office 365', 'Office Software - Marketplace Apps'],
#  ['orderwise', 'ERP Software - Accounting & Finance Software'],
#  ['mace systems',
#   'ERP Software - Wholesale, Merchant and Distribution Software'],
#  ['intercom',
#   'Artificial Intelligence Software - Conversational Intelligence Software',
#   'Collaboration & Productivity Software - Digital Adoption Platform Software',
#   'Customer Service Software - Conversational Customer Engagement Software',
#   'Customer Service Software - Customer Self-Service Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Live Chat Software',
#   'Marketing Software - Conversational Marketing Software',
#   'Artificial Intelligence Software - Conversational Intelligence Software',
#   'Collaboration & Productivity Software - Digital Adoption Platform Software',
#   'Customer Service Software - Conversational Customer Engagement Software',
#   'Customer Service Software - Customer Self-Service Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Live Chat Software',
#   'Marketing Software - Conversational Marketing Software'],
#  ['vtiger', 'Sales - CRM Software', 'Sales - CRM Software'],
#  ['desk',
#   'Content Management Systems - Digital Asset Management Software',
#   'Content Management Systems - Web Content Management Software',
#   'Content Management Systems - Digital Asset Management Software',
#   'Content Management Systems - Web Content Management Software'],
#  ['google drive',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Content Management Systems - Cloud Content Collaboration Software'],
#  ['fb messenger', 'Application Software - Messaging Software'],
#  ['super office', 'Sales - CRM Software'],
#  ['google analytics',
#   'Development Software - Application Development Software',
#   'Marketing Software - Content Marketing Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Digital Analytics Software',
#   'Development Software - Application Development Software',
#   'Marketing Software - Content Marketing Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Digital Analytics Software'],
#  ['trinet',
#   'HR Software - Core HR Software',
#   'HR Software - Time Tracking Software',
#   'HR Software - Payroll Software',
#   'HR Software - PEO Software',
#   'HR Software - Talent Management Software'],
#  ['dealsignal',
#   'Marketing Software - Market Intelligence Software',
#   'Sales - Sales Intelligence Software'],
#  ['nutshell',
#   'Sales - CRM Software',
#   'Development Software - Application Development Software',
#   'Sales - CRM Software',
#   'Development Software - Application Development Software'],
#  ['google audience center 360',
#   'Marketing Software - Display and Video Platform'],
#  ['sugar sell', 'Sales - Sales Acceleration Software'],
#  ['google cloud functions',
#   'Development Software - Cloud Platform as a Service Software'],
#  ['groove',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Intelligence Software'],
#  ['buffer', 'Marketing Software - Social Media Marketing Software'],
#  ['typeform',
#   'Content Management Systems - Online Form Builder Software',
#   'Office Software - Marketplace Apps',
#   'Content Management Systems - Online Form Builder Software',
#   'Office Software - Marketplace Apps'],
#  ['splash',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software'],
#  ['talkdesk',
#   'Sales - Auto Dialer Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Sales - Auto Dialer Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software'],
#  ['dotscience',
#   'Artificial Intelligence Software - Data Science & Machine Learning '
#   'Platforms'],
#  ['kepion', 'ERP Software - Accounting & Finance Software'],
#  ['thoughtspot',
#   'Analytics Software - Analytics Platform Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software',
#   'IT Infrastructure Software - Database Software'],
#  ['intercom.io',
#   'Customer Service Software - Customer Communications Management Software'],
#  ['clubhouse', 'Development Software - Product Management Software'],
#  ['oracle eloqua',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['slack',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Internal Communications Software'],
#  ['gumgum',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software'],
#  ['drip',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['crystal',
#   'HR Software - Talent Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software'],
#  ['bitrix24',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Development Software - Product Management Software',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Development Software - Product Management Software'],
#  ['bigquery', 'IT Infrastructure Software - Database Software'],
#  ['woocommerce',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software'],
#  ['evernote',
#   'Collaboration & Productivity Software - Note Taking Management Software'],
#  ['optimizely',
#   'Development Software - Application Development Software',
#   'Development Software - Feature Management Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Personalization Engines',
#   'Development Software - Application Development Software',
#   'Development Software - Feature Management Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Personalization Engines',
#   'Commerce Software - E-Commerce Software'],
#  ['ifs alliance',
#   'Customer Service Software - Field Service Management Software',
#   'Customer Service Software - Field Service Management Software',
#   'Customer Service Software - Field Service Management Software',
#   'Customer Service Software - Field Service Management Software'],
#  ['eventbrite',
#   'Marketing Software - (C2C) Community Marketing Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - (C2C) Community Marketing Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software',
#   'Marketing Software - Event Management Software'],
#  ['rchilli',
#   'ERP Software - Document Generation Software',
#   'ERP Software - Document Generation Software'],
#  ['hunter', 'Sales - Sales Intelligence Software'],
#  ['adobe audience manager',
#   'Digital Advertising Platforms - Data Management Platform (DMP) Software'],
#  ['syspro',
#   'ERP Software - ERP Systems ',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Discrete ERP Software',
#   'ERP Software - ERP Systems',
#   'ERP Software - Mixed Mode ERP Software',
#   'ERP Software - Process ERP Software'],
#  ['google ads',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software'],
#  ['calidore', 'Commerce Software - E-Commerce Software'],
#  ['oracle ebs', 'Sales - CRM Software'],
#  ['product hunt', 'HR Software - Talent Management Software'],
#  ['freshsales',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - Sales Analytics',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Analytics Software'],
#  ['gotowebinar',
#   'Collaboration & Productivity Software - Webinar Software',
#   'Collaboration & Productivity Software - Webinar Software',
#   'Collaboration & Productivity Software - Webinar Software',
#   'Collaboration & Productivity Software - Webinar Software'],
#  ['zendesk sell', 'Sales - CRM Software'],
#  ['formstack',
#   'Content Management Systems - Online Form Builder Software',
#   'Content Management Systems - Online Form Builder Software',
#   'Office Software - Marketplace Apps',
#   'Content Management Systems - Online Form Builder Software',
#   'Office Software - Marketplace Apps'],
#  ['formstack documents'],
#  ['google calendar',
#   'Office Software - Calendar Software',
#   'Office Software - Calendar Software',
#   'Office Software - Calendar Software',
#   'Office Software - Calendar Software',
#   'Office Software - Calendar Software',
#   'Office Software - Calendar Software'],
#  ['amazon s3 csv', 'IT Infrastructure Software - Storage Management Software'],
#  ['localytics',
#   'Development Software - Application Development Software',
#   'Marketing Software - Mobile Attribution Software',
#   'Marketing Software - Mobile Marketing Software',
#   'Marketing Software - Push Notification Software'],
#  ['oracle engagement cloud', 'Sales - CRM Software'],
#  ['edocr', 'Marketing Software - Demand Generation Software'],
#  ['urban airship', 'IT - Customer Engagement Platform'],
#  ['opensense',
#   'Marketing Software - Content Marketing Software',
#   'Marketing Software - Email Signature Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Acceleration Software'],
#  ['taptica',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software'],
#  ['clearbit',
#   'Digital Advertising Platforms - Data Management Platform (DMP) Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Market Intelligence Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Acceleration Software',
#   'Digital Advertising Platforms - Data Management Platform (DMP) Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Market Intelligence Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Intelligence Software'],
#  ['salesforce iq', 'Sales - CRM Software'],
#  ['brex', 'ERP Software - Accounting & Finance Software'],
#  ['ininbox', 'Marketing Software - Email Marketing Software'],
#  ['tact',
#   'Sales - AI Sales Assistant Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['split',
#   'Development Software - Application Development Software',
#   'Development Software - Feature Management Software'],
#  ['outreach',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['amazon redshift', 'IT Infrastructure Software - Data Warehouse Software'],
#  ['better proposals',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software'],
#  ['procore', 'Vertical Industry Software - Construction Software'],
#  ['google data studio',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software'],
#  ['maginus', 'ERP Software - Accounting & Finance Software'],
#  ['sendpulse',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Mobile Marketing Software',
#   'Marketing Software - Push Notification Software',
#   'Marketing Software - SMS Marketing Software',
#   'Marketing Software - Transactional Email Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Mobile Marketing Software',
#   'Marketing Software - Push Notification Software',
#   'Marketing Software - SMS Marketing Software',
#   'Marketing Software - Transactional Email Software'],
#  ['366 degrees', 'Marketing Software - Marketing Automation Software'],
#  ['okta',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Network Security Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Network Security Software'],
#  ['membrain',
#   'Sales - CRM Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['datananas', 'Sales - Sales Acceleration Software'],
#  ['gmail',
#   'Office Software - Email Software',
#   'Office Software - Email Software',
#   'Office Software - Email Software',
#   'Office Software - Email Software'],
#  ['microsoft outlook',
#   'Office Software - Calendar Software',
#   'Office Software - Email Software',
#   'Office Software - Email Client Software',
#   'Office Software - Calendar Software',
#   'Office Software - Calendar Software',
#   'Office Software - Email Software',
#   'Office Software - Email Client Software',
#   'Office Software - Calendar Software',
#   'Office Software - Office Suites Software',
#   'Office Software - Calendar Software',
#   'Office Software - Calendar Software'],
#  ['keen.io',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Marketing Analytics Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software',
#   'Analytics Software - Business Intelligence Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Marketing Analytics Software',
#   'Analytics Software - Business Intelligence Software'],
#  ['modata', 'Sales - Sales Analytics', 'Sales - Sales Acceleration Software'],
#  ['entelo',
#   'HR Software - Talent Management Software',
#   'HR Software - Talent Management Software'],
#  ['comscore', 'Marketing Software - Digital Analytics Software'],
#  ['google hangouts chat',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Internal Communications Software',
#   'Collaboration & Productivity Software - Internal Communications Software'],
#  ['ensighten', 'Error -'],
#  ['rollworks',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Acceleration Software'],
#  ['jira',
#   'Development Software - DevOps Software',
#   'Development Software - Product Management Software',
#   'Development Software - Product Management Software',
#   'Development Software - DevOps Software',
#   'Development Software - Product Management Software',
#   'Development Software - Product Management Software'],
#  ['adobe analytics',
#   'Development Software - Application Development Software',
#   'Marketing Software - Digital Analytics Software'],
#  ['activecampaign',
#   'Sales - CRM Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Marketing Automation Software',
#   'Sales - CRM Software'],
#  ['sonar',
#   'Customer Service Software - Conversational Customer Engagement Software',
#   'Supply Chain & Logistics Software - Other Supply & Logistics Software',
#   'Marketing Software - Conversational Marketing Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Mobile Marketing Software',
#   'Marketing Software - SMS Marketing Software'],
#  ['shopify',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - POS System',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software'],
#  ['liveramp', 'Digital Advertising Platforms - Identity Resolution Software'],
#  ['google marketing platform',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software'],
#  ['udemy', 'Vertical Industry Software - Education Software'],
#  ['google display & video 360',
#   'Marketing Software - Display and Video Platform'],
#  ['smartsheet',
#   'Marketing Software - Marketing Calendar Software',
#   'ERP Software - Project, Portfolio & Program Management Software'],
#  ['pegasus', 'Vertical Industry Software - Public Safety Software'],
#  ['yelp for business',
#   'Other Services Providers - Other B2B Service Providers'],
#  ['uberflip',
#   'Marketing Software - Content Marketing Software',
#   'Marketing Software - Content Marketing Software',
#   'Marketing Software - Content Marketing Software',
#   'Marketing Software - Content Marketing Software'],
#  ['wilson allen', 'Error -'],
#  ['hd insight', 'IT Infrastructure Software - Database Software'],
#  ['intact', 'ERP Software - Procurement Software'],
#  ['altify',
#   'Sales - Customer Revenue Optimisation Software',
#   'Sales - Sales Acceleration Software'],
#  ['getaccept',
#   'Sales - Contract Management Software',
#   'Sales - Contract Management Software',
#   'Sales - E-Signature Software',
#   'Sales - Quote Management Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - E-Signature Software',
#   'Sales - Quote Management Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['box',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Content Management Systems - Cloud Content Collaboration Software',
#   'Content Management Systems - Cloud Content Collaboration Software'],
#  ['funnelflare',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['keap (formerly infusionsoft)',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Marketing Software - Marketing Automation Software',
#   'Sales - CRM Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['time', 'Collaboration & Productivity Software - Productivity Bots Software'],
#  ['connectwise sell',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Softwar',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software'],
#  ['import2', 'IT Infrastructure Software - Data Integration Software'],
#  ['quickbooks online',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Accounting & Finance Software'],
#  ['base',
#   'Marketing Software - Local Marketing Software',
#   'ERP Software - Project, Portfolio & Program Management Software'],
#  ['sage intacct',
#   'ERP Software - Accounting & Finance Software',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - ERP Systems'],
#  ['ispot.tv', 'Marketing Software - Marketing Analytics Software'],
#  ['twilio sendgrid email api',
#   'Marketing Software - Email Deliverability Software',
#   'Marketing Software - Transactional Email Software',
#   'Marketing Software - Email Deliverability Software',
#   'Marketing Software - Email Deliverability Software',
#   'Marketing Software - Transactional Email Software',
#   'Marketing Software - Email Deliverability Software'],
#  ['exchequer', 'ERP Software - Accounting & Finance Software'],
#  ['zoominfo powered by discoverorg',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Intelligence Software',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Intelligence Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Market Intelligence Software - Market Intelligence Software'],
#  ['one click politics',
#   'Vertical Industry Software - Political Campaign Software'],
#  ['kerridge', 'ERP Software - Automotive Aftermarket Software'],
#  ['statsocial', 'Marketing Software - Social Media Marketing Software'],
#  ['elan', 'Design Software - Audio and Video Recording Software'],
#  ['openprise',
#   'IT Infrastructure Software - Data Quality Software',
#   'Marketing Software - Attribution Software',
#   'Marketing Software - Customer Data Platform (CDP) Software'],
#  ['bmi',
#   'Supply Chain & Logistics Software - Supply Chain Management Software'],
#  ['amocrm', 'Sales - CRM Software'],
#  ['pipedrive', 'Sales - CRM Software'],
#  ['8x8', 'Collaboration & Productivity Software - VoIP Providers'],
#  ['lattice',
#   'Collaboration & Productivity Software - Objectives & Key Results Software',
#   'ERP Software - 3D Parts Catalogs Software'],
#  ['teradata', 'IT - Data and Analytics Software'],
#  ['hubspot sales hub',
#   'Office Software - Business Card Scanning Software',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['cipher', 'Marketing Software - Competitive Intelligence Tools Software'],
#  ['cisco webex meetings',
#   'Collaboration & Productivity Software - Team Collaboration Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Collaboration & Productivity Software - Team Collaboration Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Collaboration & Productivity Software - Video Conferencing Software'],
#  ['mailchimp',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Email Deliverability Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Email Deliverability Software',
#   'Marketing Software - Email Marketing Software'],
#  ['snowflake',
#   'IT Infrastructure Software - Database Software',
#   'IT Infrastructure Software - Data Warehouse Software'],
#  ['clickfunnels',
#   'Content Management Systems - Website Builder Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Content Management Systems - Website Builder Software',
# ...
#   'Marketing Software - Event Management Software'],
#  ['trueinfluence', 'Marketing - Automation Software'],
#  ['asana',
#   'Content Management Systems - Online Proofing Software',
#   'Development Software - Product Management Software',
#   'Marketing Software - Marketing Calendar Software',
#   'Content Management Systems - Online Proofing Software',
#   'Development Software - Product Management Software',
#   'Marketing Software - Marketing Calendar Software',
#   'ERP Software - Project, Portfolio & Program Management Software',
#   'ERP Software - Project, Portfolio & Program Management Software'],
#  ['constant contact',
#   'Content Management Systems - Website Builder Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Marketing Software - Email Deliverability Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Event Management Software',
#   'Content Management Systems - Website Builder Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Marketing Software - Email Deliverability Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Event Management Software',
#   'Commerce Software - E-Commerce Software'],
#  ['sage act', 'Sales - CRM Software'],
#  ['volusion',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software'],
#  ['google search console', 'Marketing Software - SEO Software'],
#  ['everstring',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Acceleration Software'],
#  ['close',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - SMS Marketing Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - SMS Marketing Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['citrix podio',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'ERP Software - Project, Portfolio & Program Management Software',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'ERP Software - Project, Portfolio & Program Management Software',
#   'ERP Software - Project, Portfolio & Program Management Software',
#   'ERP Software - Project, Portfolio & Program Management Software'],
#  ['marketo',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Mobile Marketing Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Mobile Marketing Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['facebook ads', 'Error - '],
#  ['.net core', 'Development Software - Application Development Software'],
#  ['salesloft',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Acceleration Software'],
#  ['sharpspring',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['aweber',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Email Testing Software',
#   'Marketing Software - Pop-Up Builder Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Email Marketing Software',
#   'Marketing Software - Email Template Builder Software',
#   'Marketing Software - Email Testing Software',
#   'Marketing Software - Pop-Up Builder Software',
#   'Marketing Software - Conversion Rate Optimization Software'],
#  ['demand base',
#   'Marketing software - Account-Based Marketing Software',
#   'Marketing Software - Account-based Marketing Software'],
#  ['scheduleonce',
#   'Office Software - Marketplace Apps',
#   'Office Software - Online Appointment Scheduling Software',
#   'Office Software - Marketplace Apps',
#   'Office Software - Online Appointment Scheduling Software'],
#  ['datatron',
#   'Artificial Intelligence Software - AI & Machine Learning Operationalisation '
#   'Software'],
#  ['hubspot marketing hub',
#   'Content Management Systems - Web Content Management Software',
#   'Content Management Systems - Website Builder Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Marketing Software - Conversational Marketing Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Marketing Analytics Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Social Media Marketing Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Marketing Software - Marketing Automation Software',
#   'Content Management Systems - Web Content Management Software',
#   'Content Management Systems - Website Builder Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Marketing Software - Conversational Marketing Software',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Marketing Analytics Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Social Media Marketing Software',
#   'Digital Advertising Platforms - Advertiser Campaign Management Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['highrise', 'Sales - CRM Software'],
#  ['xero',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Accounting & Finance Software'],
#  ['salesforce service cloud',
#   'Customer Service Software - Customer Self-Service Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Live Chat Software',
#   'Customer Service Software - Social Customer Service Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Customer Self-Service Software',
#   'Customer Service Software - HelpDesk Software',
#   'Customer Service Software - Live Chat Software',
#   'Customer Service Software - Social Customer Service Software',
#   'Customer Service Software - Help Desk Software'],
#  ['salesforce crm',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software'],
#  ['moneyguidepro',
#   'Vertical Industry Software - Financial Services Software',
#   'ERP Software - Accounting & Finance Software'],
#  ['discoverorg',
#   'B2B Marketplace Platforms - On-Demand Delivery Software',
#   'B2B Marketplace Platforms - On-Demand Delivery Software'],
#  ['clari', 'Sales - Sales Analytics', 'Sales - AI Sales Assistant Software'],
#  ['leadspace',
#   'Marketing Software - Customer Data Platform (CDP) Software',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Intelligence Software'],
#  ['insightly crm',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software'],
#  ['nimble',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - CRM Software',
#   'Sales - Sales Acceleration Software',
#   'Sales - Sales Intelligence Software'],
#  ['activedemand',
#   'Marketing Software - Inbound Call Tracking Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Inbound Call Tracking Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['less annoying crm', 'Sales - CRM Software'],
#  ['g suite',
#   'Office Software - Marketplace Apps',
#   'Office Software - Office Suites Software',
#   'Office Software - Marketplace Apps',
#   'Office Software - Office Suites Software'],
#  ['adobe target',
#   'Marketing Software - Conversion Rate Optimization Software',
#   'Marketing Software - Personalization Software'],
#  ['circleloop', 'Collaboration & Productivity Software - VoIP Providers'],
#  ['recruitee',
#   'HR Software - Talent Management Software',
#   'HR Software - Talent Management Software'],
#  ['vidyard', 'Design Software - Video Software'],
#  ['karmak', 'Error -'],
#  ['ponto', 'Vertical Industry Software - Accounting & Finance Software'],
#  ['ping identity',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software',
#   'Security Software - Identity Management Software'],
#  ['linkedin sales navigator',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Intelligence Softwar',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Intelligence Software',
#   'Sales - Sales Intelligence Software'],
#  ['docusign',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Sales - E-Signature Software',
#   'Sales - E-Signature Software',
#   'Collaboration & Productivity Software - G Suite Marketplace Software',
#   'Sales - E-Signature Software',
#   'Sales - E-Signature Software'],
#  ['lucidchart',
#   'Collaboration & Productivity Software - Team Collaboration Software',
#   'Office Software - Marketplace Apps',
#   'Design Software - Diagramming Software'],
#  ['triblio', 'Marketing Software - Content Marketing Software'],
#  ['adbeat',
#   'Digital Advertising Platforms - Other Digital Advertising Software'],
#  ['maximizer crm', 'Sales - CRM Software'],
#  ['adobe core services',
#   'Marketing Software - Location-Based Marketing Software'],
#  ['6sense', 'Marketing Software - Demand Generation Software'],
#  ['mopub',
#   'Digital Advertising Platforms - Publisher Ad Management Software',
#   'Digital Advertising Platforms - Publisher Ad Management Software'],
#  ['five9',
#   'Sales - Auto Dialer Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Governance, Risk & Compliance Software - Call Compliance Software',
#   'Sales - Auto Dialer Software',
#   'Customer Service Software - Contact Center Software',
#   'Customer Service Software - Contact Center Software',
#   'Governance, Risk & Compliance Software - Call Compliance Software'],
#  ['act-on',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Marketing Analytics Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Personalization Software',
#   'Marketing Software - SEO Software',
#   'Marketing Software - Social Media Marketing Software',
#   'Marketing Software - Social Media Marketing Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Demand Generation Software',
#   'Marketing Software - Marketing Analytics Software',
#   'Marketing Software - Marketing Automation Software',
#   'Marketing Software - Personalization Software',
#   'Marketing Software - SEO Software',
#   'Marketing Software - Social Media Marketing Software',
#   'Marketing Software - Social Media Marketing Software',
#   'Marketing Software - Marketing Automation Software'],
#  ['twitter',
#   'Collaboration & Productivity Software - Social Networks Software'],
#  ['datanyze',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Intelligence Software',
#   'Marketing Software - Demand Generation Software',
#   'Sales - Sales Intelligence Software'],
#  ['dataproc', 'Analytics Software - Analytics Platform Software'],
#  ['linkedin premium',
#   'Collaboration & Productivity Software - Social Networks Software',
#   'Collaboration & Productivity Software - Social Networks Software',
#   'Collaboration & Productivity Software - Social Networks Software',
#   'Collaboration & Productivity Software - Social Networks Software'],
#  ['webjaguar',
#   'Commerce Software - E-Commerce Software',
#   'Commerce Software - E-Commerce Software'],
#  ['primaerp', 'HR Software - Time Tracking Software'],
#  ['matomo', 'Marketing Software - Content Marketing Software'],
#  ['pandadoc',
#   'Sales - Contract Management Software',
#   'Sales - E-Signature Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'Sales - Contract Management Software',
#   'Sales - E-Signature Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'Sales - Quote Management Software',
#   'ERP Software - Document Generation Software'],
#  ['sap erp',
#   'ERP Software - ERP Systems',
#   'ERP Software - Accounting & Finance Software',
#   'ERP Software - Discrete ERP Software',
#   'ERP Software - Distribution ERP Software',
#   'ERP Software - ERP Systems',
#   'ERP Software - ETO ERP Software',
#   'ERP Software - Mixed Mode ERP Software',
#   'ERP Software - Process ERP Software'],
#  ['gotomeeting',
#   'Collaboration & Productivity Software - Team Collaboration Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Collaboration & Productivity Software - Team Collaboration Software',
#   'Collaboration & Productivity Software - Video Conferencing Software',
#   'Collaboration & Productivity Software - Video Conferencing Software'],
#  ['athena', 'IT Infrastructure Software - Remote Support Software'],
#  ['harvest',
#   'HR Software - Time Tracking Software',
#   'ERP Software - Project, Portfolio & Program Management Software'],
#  ['mailshake',
#   'Marketing Software - Blogger Outreach Software',
#   'Sales - Sales Acceleration Software',
#   'Marketing Software - Blogger Outreach Software',
#   'Sales - Sales Acceleration Software'],
#  ['copper', 'Sales - CRM Software'],
#  ['dropbox',
#   'Content Management Systems - Cloud Content Collaboration Software'],
#  ['plaid', 'Data Privacy Software - Identity Verification Software'],
#  ['microsoft dynamics 365 sales',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software',
#   'Sales - CRM Software'],
#  ['batchbook', 'Customer Service Software - Contact Center Software'],
#  ['sensor tower',
#   'Development Software - Application Development Software',
#   'Marketing Software - App Store Optimization Software'],
#  ['oracle cx ', 'Sales - Customer Experience Software'],
#  ['keeptruckin',
#   'Supply Chain & Logistics Software - Distribution Software',
#   'Supply Chain & Logistics Software - Distribution Software'],
#  ['signal hq', 'Sales - Sales Intelligence Software'],
#  ['hellosign', 'Sales - E-Signature Software'],
#  ['voilanorbert',
#   'Office Software - Email Verification Software',
#   'Marketing Software - Demand Generation Software'],
#  ['citus data', 'IT Infrastructure Software - Database Software']]
